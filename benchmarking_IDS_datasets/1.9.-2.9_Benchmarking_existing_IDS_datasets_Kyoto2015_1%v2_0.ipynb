# %% [markdown]
# # Kyoto 2015 - Benchmarking
# ## 0. Notebook initialization

# %%
# Mount your Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from psutil import virtual_memory
from tabulate import tabulate

# Function to get CPU information
def get_cpu_info():
    cpu_info = os.popen('lscpu').read()
    return cpu_info

# Function to get RAM information
def get_ram_info():
    ram = virtual_memory()
    total_ram = f"{ram.total / 1e9:.2f} GB"
    available_ram = f"{ram.available / 1e9:.2f} GB"
    return total_ram, available_ram

# Function to get GPU information
def get_gpu_info():
    # Execute nvidia-smi and get its output
    gpu_info = os.popen('nvidia-smi --query-gpu=name,memory.total,memory.used,memory.free --format=csv,noheader,nounits').read().strip()

    # Split the output to get individual GPU details
    details = gpu_info.split(", ")

    # Return GPU name, total, used, and free memory
    return details[0], f"{details[1]} MB", f"{details[2]} MB", f"{details[3]} MB"

# Collect system information
cpu_info = get_cpu_info()
total_ram, available_ram = get_ram_info()
try:
  gpu_name, gpu_total_memory, gpu_used_memory, gpu_free_memory = get_gpu_info()
except:
  gpu_name, gpu_total_memory, gpu_used_memory, gpu_free_memory = 'null',0,0,0

# Extract relevant CPU information
cpu_type = ""
cpu_architecture = ""

for line in cpu_info.splitlines():
    if "Model name:" in line:
        cpu_type = line.split(":")[1].strip()
    elif "Architecture:" in line:
        cpu_architecture = line.split(":")[1].strip()

# Create a table
table = [
    ["CPU Type", cpu_type],
    ["CPU Architecture", cpu_architecture],
    ["Total RAM", total_ram],
    ["Available RAM", available_ram],
    ["GPU Name", gpu_name],
    ["GPU Total Memory", gpu_total_memory],
    ["GPU Used Memory", gpu_used_memory],
    ["GPU Free Memory", gpu_free_memory]
]

# Display the table
print(tabulate(table, headers=["Characteristic", "Value"], tablefmt="pretty"))
# Out:
# +------------------+--------------------------------+
# |  Characteristic  |             Value              |
# +------------------+--------------------------------+
# |     CPU Type     | Intel(R) Xeon(R) CPU @ 2.20GHz |
# | CPU Architecture |             x86_64             |
# |    Total RAM     |            54.76 GB            |
# |  Available RAM   |            53.26 GB            |
# |     GPU Name     |              null              |
# | GPU Total Memory |               0                |
# | GPU Used Memory  |               0                |
# | GPU Free Memory  |               0                |
# +------------------+--------------------------------+

# %% [markdown]
# ## 1. Data Acquisition and Preprocessing
#
# In this section, we focus on acquiring the above mentioned datasets.

# %% [markdown]
# ### 1.9. Kyoto 2006+ dataset
#
# The Kyoto (Kyoto 2006+) dataset, often referred to as the Kyoto University Honeypot Dataset, stands out for its honeypot-based intrusion detection and analysis methodology. Developed by Kyoto University, this dataset plays a vital role in the field of network security. It captures a wide array of cyber threats and attacks through honeypot sensors, which mimic vulnerable systems, attracting malicious activity for analysis. This approach allows researchers to gather real-world data on various types of attacks, including but not limited to, network scanning, brute force, and distributed denial of service (DDoS) attacks. This resource is invaluable for honing intrusion detection systems and advancing cybersecurity research and practices.
#
# Due to the large amounts of data available in the Kyoto datasets (126 GB - 3257 files), we will focus only on the data gathered in the last year of the experiment, 2015. You can download the entire dataset, by executing the following routine:

# %% [markdown]
# ### Download and Unzip Kyoto 2006+ dataset

# %% [markdown]
# ***I'm using Bash commands for download, unzip, and initial preprocessing as it is much faster and the large dataset size may causes crashes of Python.***

# %%
# !wget --mirror -np -nH --cut-dirs=1 -P '/content/drive/MyDrive/Kyoto2006+' -N -r -A '*' https://www.takakura.com/Kyoto_data/new_data201704/
# Out:
# --2023-10-13 11:41:37--  https://www.takakura.com/Kyoto_data/new_data201704/
# Resolving www.takakura.com (www.takakura.com)... 150.100.120.5, 2001:2f8:3a:2100::5
# Connecting to www.takakura.com (www.takakura.com)|150.100.120.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9913 (9.7K) [text/html]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/index.html’
#
# new_data201704/inde 100%[===================>]   9.68K  --.-KB/s    in 0.001s
#
# 2023-10-13 11:41:38 (10.5 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/index.html’ saved [9913/9913]
#
# Loading robots.txt; please ignore errors.
# --2023-10-13 11:41:38--  https://www.takakura.com/robots.txt
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-10-13 11:41:38 ERROR 404: Not Found.
#
# --2023-10-13 11:41:38--  https://www.takakura.com/Kyoto_data/new_data201704/2006/2006.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90748747 (87M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2006/2006.zip’
#
# new_data201704/2006 100%[===================>]  86.54M  17.0MB/s    in 6.2s
#
# 2023-10-13 11:41:45 (13.9 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2006/2006.zip’ saved [90748747/90748747]
#
# --2023-10-13 11:41:45--  https://www.takakura.com/Kyoto_data/new_data201704/2006/200611.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 27397981 (26M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2006/200611.zip’
#
# new_data201704/2006 100%[===================>]  26.13M  17.3MB/s    in 1.5s
#
# 2023-10-13 11:41:47 (17.3 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2006/200611.zip’ saved [27397981/27397981]
#
# --2023-10-13 11:41:47--  https://www.takakura.com/Kyoto_data/new_data201704/2006/200612.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 63350630 (60M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2006/200612.zip’
#
# new_data201704/2006 100%[===================>]  60.42M  15.4MB/s    in 3.9s
#
# 2023-10-13 11:41:51 (15.4 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2006/200612.zip’ saved [63350630/63350630]
#
# --2023-10-13 11:41:51--  https://www.takakura.com/Kyoto_data/new_data201704/2007/2007.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 633463703 (604M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/2007.zip’
#
# new_data201704/2007 100%[===================>] 604.12M  16.4MB/s    in 37s
#
# 2023-10-13 11:42:27 (16.5 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/2007.zip’ saved [633463703/633463703]
#
# --2023-10-13 11:42:27--  https://www.takakura.com/Kyoto_data/new_data201704/2007/200701.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 43382104 (41M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200701.zip’
#
# new_data201704/2007 100%[===================>]  41.37M  16.6MB/s    in 2.5s
#
# 2023-10-13 11:42:30 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200701.zip’ saved [43382104/43382104]
#
# --2023-10-13 11:42:30--  https://www.takakura.com/Kyoto_data/new_data201704/2007/200702.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 48609162 (46M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200702.zip’
#
# new_data201704/2007 100%[===================>]  46.36M  17.2MB/s    in 2.7s
#
# 2023-10-13 11:42:33 (17.2 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200702.zip’ saved [48609162/48609162]
#
# --2023-10-13 11:42:33--  https://www.takakura.com/Kyoto_data/new_data201704/2007/200703.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42952801 (41M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200703.zip’
#
# new_data201704/2007 100%[===================>]  40.96M  17.9MB/s    in 2.3s
#
# 2023-10-13 11:42:35 (17.9 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200703.zip’ saved [42952801/42952801]
#
# --2023-10-13 11:42:35--  https://www.takakura.com/Kyoto_data/new_data201704/2007/200704.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 37159678 (35M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200704.zip’
#
# new_data201704/2007 100%[===================>]  35.44M  15.8MB/s    in 2.2s
#
# 2023-10-13 11:42:38 (15.8 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200704.zip’ saved [37159678/37159678]
#
# --2023-10-13 11:42:38--  https://www.takakura.com/Kyoto_data/new_data201704/2007/200705.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 46729201 (45M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200705.zip’
#
# new_data201704/2007 100%[===================>]  44.56M  14.8MB/s    in 3.0s
#
# 2023-10-13 11:42:41 (14.8 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200705.zip’ saved [46729201/46729201]
#
# --2023-10-13 11:42:41--  https://www.takakura.com/Kyoto_data/new_data201704/2007/200706.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 47908064 (46M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200706.zip’
#
# new_data201704/2007 100%[===================>]  45.69M  16.0MB/s    in 2.9s
#
# 2023-10-13 11:42:44 (16.0 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200706.zip’ saved [47908064/47908064]
#
# --2023-10-13 11:42:44--  https://www.takakura.com/Kyoto_data/new_data201704/2007/200707.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 56175035 (54M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200707.zip’
#
# new_data201704/2007 100%[===================>]  53.57M  17.0MB/s    in 3.2s
#
# 2023-10-13 11:42:47 (17.0 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200707.zip’ saved [56175035/56175035]
#
# --2023-10-13 11:42:47--  https://www.takakura.com/Kyoto_data/new_data201704/2007/200708.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 52025898 (50M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200708.zip’
#
# new_data201704/2007 100%[===================>]  49.62M  16.1MB/s    in 3.1s
#
# 2023-10-13 11:42:51 (16.1 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200708.zip’ saved [52025898/52025898]
#
# --2023-10-13 11:42:51--  https://www.takakura.com/Kyoto_data/new_data201704/2007/200709.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 62820287 (60M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200709.zip’
#
# new_data201704/2007 100%[===================>]  59.91M  14.9MB/s    in 4.0s
#
# 2023-10-13 11:42:55 (14.9 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200709.zip’ saved [62820287/62820287]
#
# --2023-10-13 11:42:55--  https://www.takakura.com/Kyoto_data/new_data201704/2007/200710.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 52664496 (50M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200710.zip’
#
# new_data201704/2007 100%[===================>]  50.22M  17.3MB/s    in 2.9s
#
# 2023-10-13 11:42:58 (17.3 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200710.zip’ saved [52664496/52664496]
#
# --2023-10-13 11:42:58--  https://www.takakura.com/Kyoto_data/new_data201704/2007/200711.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 65566622 (63M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200711.zip’
#
# new_data201704/2007 100%[===================>]  62.53M  17.0MB/s    in 3.7s
#
# 2023-10-13 11:43:02 (17.0 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200711.zip’ saved [65566622/65566622]
#
# --2023-10-13 11:43:02--  https://www.takakura.com/Kyoto_data/new_data201704/2007/200712.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 77470439 (74M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200712.zip’
#
# new_data201704/2007 100%[===================>]  73.88M  17.2MB/s    in 4.3s
#
# 2023-10-13 11:43:06 (17.2 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200712.zip’ saved [77470439/77470439]
#
# --2023-10-13 11:43:06--  https://www.takakura.com/Kyoto_data/new_data201704/2008/2008.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1070103463 (1021M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/2008.zip’
#
# new_data201704/2008 100%[===================>]   1021M  17.1MB/s    in 62s
#
# 2023-10-13 11:44:08 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/2008.zip’ saved [1070103463/1070103463]
#
# --2023-10-13 11:44:08--  https://www.takakura.com/Kyoto_data/new_data201704/2008/200801.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 101358436 (97M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200801.zip’
#
# new_data201704/2008 100%[===================>]  96.66M  17.2MB/s    in 5.6s
#
# 2023-10-13 11:44:14 (17.2 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200801.zip’ saved [101358436/101358436]
#
# --2023-10-13 11:44:14--  https://www.takakura.com/Kyoto_data/new_data201704/2008/200802.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 61378848 (59M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200802.zip’
#
# new_data201704/2008 100%[===================>]  58.54M  16.9MB/s    in 3.5s
#
# 2023-10-13 11:44:18 (16.9 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200802.zip’ saved [61378848/61378848]
#
# --2023-10-13 11:44:18--  https://www.takakura.com/Kyoto_data/new_data201704/2008/200803.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92465625 (88M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200803.zip’
#
# new_data201704/2008 100%[===================>]  88.18M  15.2MB/s    in 5.8s
#
# 2023-10-13 11:44:24 (15.2 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200803.zip’ saved [92465625/92465625]
#
# --2023-10-13 11:44:24--  https://www.takakura.com/Kyoto_data/new_data201704/2008/200804.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 119065401 (114M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200804.zip’
#
# new_data201704/2008 100%[===================>] 113.55M  16.6MB/s    in 7.1s
#
# 2023-10-13 11:44:31 (16.0 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200804.zip’ saved [119065401/119065401]
#
# --2023-10-13 11:44:31--  https://www.takakura.com/Kyoto_data/new_data201704/2008/200805.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 101726114 (97M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200805.zip’
#
# new_data201704/2008 100%[===================>]  97.01M  16.6MB/s    in 5.8s
#
# 2023-10-13 11:44:37 (16.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200805.zip’ saved [101726114/101726114]
#
# --2023-10-13 11:44:37--  https://www.takakura.com/Kyoto_data/new_data201704/2008/200806.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 96078368 (92M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200806.zip’
#
# new_data201704/2008 100%[===================>]  91.63M  17.4MB/s    in 5.4s
#
# 2023-10-13 11:44:43 (17.0 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200806.zip’ saved [96078368/96078368]
#
# --2023-10-13 11:44:43--  https://www.takakura.com/Kyoto_data/new_data201704/2008/200807.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 96487882 (92M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200807.zip’
#
# new_data201704/2008 100%[===================>]  92.02M  16.8MB/s    in 5.5s
#
# 2023-10-13 11:44:48 (16.8 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200807.zip’ saved [96487882/96487882]
#
# --2023-10-13 11:44:48--  https://www.takakura.com/Kyoto_data/new_data201704/2008/200808.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 101805441 (97M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200808.zip’
#
# new_data201704/2008 100%[===================>]  97.09M  17.5MB/s    in 5.9s
#
# 2023-10-13 11:44:54 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200808.zip’ saved [101805441/101805441]
#
# --2023-10-13 11:44:54--  https://www.takakura.com/Kyoto_data/new_data201704/2008/200809.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 95109265 (91M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200809.zip’
#
# new_data201704/2008 100%[===================>]  90.70M  17.0MB/s    in 5.4s
#
# 2023-10-13 11:45:00 (16.9 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200809.zip’ saved [95109265/95109265]
#
# --2023-10-13 11:45:00--  https://www.takakura.com/Kyoto_data/new_data201704/2008/200810.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 72603613 (69M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200810.zip’
#
# new_data201704/2008 100%[===================>]  69.24M  17.2MB/s    in 4.0s
#
# 2023-10-13 11:45:04 (17.2 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200810.zip’ saved [72603613/72603613]
#
# --2023-10-13 11:45:04--  https://www.takakura.com/Kyoto_data/new_data201704/2008/200811.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60249894 (57M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200811.zip’
#
# new_data201704/2008 100%[===================>]  57.46M  16.8MB/s    in 3.4s
#
# 2023-10-13 11:45:08 (16.8 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200811.zip’ saved [60249894/60249894]
#
# --2023-10-13 11:45:08--  https://www.takakura.com/Kyoto_data/new_data201704/2008/200812.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 71774660 (68M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200812.zip’
#
# new_data201704/2008 100%[===================>]  68.45M  17.0MB/s    in 4.0s
#
# 2023-10-13 11:45:12 (17.1 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200812.zip’ saved [71774660/71774660]
#
# --2023-10-13 11:45:12--  https://www.takakura.com/Kyoto_data/new_data201704/2009/2009.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2155389856 (2.0G) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/2009.zip’
#
# new_data201704/2009 100%[===================>]   2.01G  16.8MB/s    in 2m 4s
#
# 2023-10-13 11:47:16 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/2009.zip’ saved [2155389856/2155389856]
#
# --2023-10-13 11:47:16--  https://www.takakura.com/Kyoto_data/new_data201704/2009/200901.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 124554243 (119M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200901.zip’
#
# new_data201704/2009 100%[===================>] 118.78M  15.4MB/s    in 7.7s
#
# 2023-10-13 11:47:24 (15.5 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200901.zip’ saved [124554243/124554243]
#
# --2023-10-13 11:47:24--  https://www.takakura.com/Kyoto_data/new_data201704/2009/200902.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 109839467 (105M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200902.zip’
#
# new_data201704/2009 100%[===================>] 104.75M  16.3MB/s    in 6.5s
#
# 2023-10-13 11:47:31 (16.1 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200902.zip’ saved [109839467/109839467]
#
# --2023-10-13 11:47:31--  https://www.takakura.com/Kyoto_data/new_data201704/2009/200903.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 113919623 (109M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200903.zip’
#
# new_data201704/2009 100%[===================>] 108.64M  15.3MB/s    in 7.0s
#
# 2023-10-13 11:47:38 (15.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200903.zip’ saved [113919623/113919623]
#
# --2023-10-13 11:47:38--  https://www.takakura.com/Kyoto_data/new_data201704/2009/200904.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 221168860 (211M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200904.zip’
#
# new_data201704/2009 100%[===================>] 210.92M  15.3MB/s    in 14s
#
# 2023-10-13 11:47:52 (15.4 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200904.zip’ saved [221168860/221168860]
#
# --2023-10-13 11:47:52--  https://www.takakura.com/Kyoto_data/new_data201704/2009/200905.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 138300194 (132M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200905.zip’
#
# new_data201704/2009 100%[===================>] 131.89M  17.0MB/s    in 7.8s
#
# 2023-10-13 11:48:00 (16.9 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200905.zip’ saved [138300194/138300194]
#
# --2023-10-13 11:48:00--  https://www.takakura.com/Kyoto_data/new_data201704/2009/200906.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 127325413 (121M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200906.zip’
#
# new_data201704/2009 100%[===================>] 121.43M  16.5MB/s    in 7.3s
#
# 2023-10-13 11:48:07 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200906.zip’ saved [127325413/127325413]
#
# --2023-10-13 11:48:07--  https://www.takakura.com/Kyoto_data/new_data201704/2009/200907.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 164920713 (157M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200907.zip’
#
# new_data201704/2009 100%[===================>] 157.28M  16.8MB/s    in 9.4s
#
# 2023-10-13 11:48:17 (16.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200907.zip’ saved [164920713/164920713]
#
# --2023-10-13 11:48:17--  https://www.takakura.com/Kyoto_data/new_data201704/2009/200908.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 146524665 (140M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200908.zip’
#
# new_data201704/2009 100%[===================>] 139.74M  17.3MB/s    in 8.3s
#
# 2023-10-13 11:48:25 (16.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200908.zip’ saved [146524665/146524665]
#
# --2023-10-13 11:48:25--  https://www.takakura.com/Kyoto_data/new_data201704/2009/200909.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 153180784 (146M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200909.zip’
#
# new_data201704/2009 100%[===================>] 146.08M  17.1MB/s    in 8.7s
#
# 2023-10-13 11:48:34 (16.9 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200909.zip’ saved [153180784/153180784]
#
# --2023-10-13 11:48:34--  https://www.takakura.com/Kyoto_data/new_data201704/2009/200910.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 210077262 (200M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200910.zip’
#
# new_data201704/2009 100%[===================>] 200.34M  16.5MB/s    in 12s
#
# 2023-10-13 11:48:46 (16.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200910.zip’ saved [210077262/210077262]
#
# --2023-10-13 11:48:46--  https://www.takakura.com/Kyoto_data/new_data201704/2009/200911.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 180994895 (173M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200911.zip’
#
# new_data201704/2009 100%[===================>] 172.61M  16.8MB/s    in 10s
#
# 2023-10-13 11:48:57 (16.5 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200911.zip’ saved [180994895/180994895]
#
# --2023-10-13 11:48:57--  https://www.takakura.com/Kyoto_data/new_data201704/2009/200912.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 464583821 (443M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200912.zip’
#
# new_data201704/2009 100%[===================>] 443.06M  16.6MB/s    in 27s
#
# 2023-10-13 11:49:24 (16.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200912.zip’ saved [464583821/464583821]
#
# --2023-10-13 11:49:24--  https://www.takakura.com/Kyoto_data/new_data201704/2010/2010.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5165553831 (4.8G) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/2010.zip’
#
# new_data201704/2010 100%[===================>]   4.81G  17.1MB/s    in 4m 54s
#
# 2023-10-13 11:54:18 (16.8 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/2010.zip’ saved [5165553831/5165553831]
#
# --2023-10-13 11:54:18--  https://www.takakura.com/Kyoto_data/new_data201704/2010/201001.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 357673193 (341M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201001.zip’
#
# new_data201704/2010 100%[===================>] 341.10M  16.0MB/s    in 22s
#
# 2023-10-13 11:54:40 (15.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201001.zip’ saved [357673193/357673193]
#
# --2023-10-13 11:54:40--  https://www.takakura.com/Kyoto_data/new_data201704/2010/201002.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 164336596 (157M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201002.zip’
#
# new_data201704/2010 100%[===================>] 156.72M  15.7MB/s    in 9.8s
#
# 2023-10-13 11:54:50 (16.0 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201002.zip’ saved [164336596/164336596]
#
# --2023-10-13 11:54:50--  https://www.takakura.com/Kyoto_data/new_data201704/2010/201003.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 223495763 (213M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201003.zip’
#
# new_data201704/2010 100%[===================>] 213.14M  15.2MB/s    in 14s
#
# 2023-10-13 11:55:05 (14.8 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201003.zip’ saved [223495763/223495763]
#
# --2023-10-13 11:55:05--  https://www.takakura.com/Kyoto_data/new_data201704/2010/201004.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 547454705 (522M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201004.zip’
#
# new_data201704/2010 100%[===================>] 522.09M  16.6MB/s    in 33s
#
# 2023-10-13 11:55:38 (16.0 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201004.zip’ saved [547454705/547454705]
#
# --2023-10-13 11:55:38--  https://www.takakura.com/Kyoto_data/new_data201704/2010/201005.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 498974552 (476M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201005.zip’
#
# new_data201704/2010 100%[===================>] 475.86M  17.2MB/s    in 28s
#
# 2023-10-13 11:56:06 (16.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201005.zip’ saved [498974552/498974552]
#
# --2023-10-13 11:56:06--  https://www.takakura.com/Kyoto_data/new_data201704/2010/201006.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 591103617 (564M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201006.zip’
#
# new_data201704/2010 100%[===================>] 563.72M  17.1MB/s    in 34s
#
# 2023-10-13 11:56:40 (16.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201006.zip’ saved [591103617/591103617]
#
# --2023-10-13 11:56:40--  https://www.takakura.com/Kyoto_data/new_data201704/2010/201007.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 486428403 (464M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201007.zip’
#
# new_data201704/2010 100%[===================>] 463.89M  16.7MB/s    in 28s
#
# 2023-10-13 11:57:09 (16.5 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201007.zip’ saved [486428403/486428403]
#
# --2023-10-13 11:57:09--  https://www.takakura.com/Kyoto_data/new_data201704/2010/201008.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 532935453 (508M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201008.zip’
#
# new_data201704/2010 100%[===================>] 508.25M  17.0MB/s    in 31s
#
# 2023-10-13 11:57:40 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201008.zip’ saved [532935453/532935453]
#
# --2023-10-13 11:57:40--  https://www.takakura.com/Kyoto_data/new_data201704/2010/201009.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 467119156 (445M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201009.zip’
#
# new_data201704/2010 100%[===================>] 445.48M  16.8MB/s    in 27s
#
# 2023-10-13 11:58:07 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201009.zip’ saved [467119156/467119156]
#
# --2023-10-13 11:58:07--  https://www.takakura.com/Kyoto_data/new_data201704/2010/201010.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 469794917 (448M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201010.zip’
#
# new_data201704/2010 100%[===================>] 448.03M  17.1MB/s    in 27s
#
# 2023-10-13 11:58:34 (16.5 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201010.zip’ saved [469794917/469794917]
#
# --2023-10-13 11:58:34--  https://www.takakura.com/Kyoto_data/new_data201704/2010/201011.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 422832841 (403M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201011.zip’
#
# new_data201704/2010 100%[===================>] 403.24M  17.0MB/s    in 24s
#
# 2023-10-13 11:58:59 (16.5 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201011.zip’ saved [422832841/422832841]
#
# --2023-10-13 11:58:59--  https://www.takakura.com/Kyoto_data/new_data201704/2010/201012.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 403403935 (385M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201012.zip’
#
# new_data201704/2010 100%[===================>] 384.72M  17.0MB/s    in 23s
#
# 2023-10-13 11:59:22 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201012.zip’ saved [403403935/403403935]
#
# --2023-10-13 11:59:22--  https://www.takakura.com/Kyoto_data/new_data201704/2011/2011.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2128043906 (2.0G) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/2011.zip’
#
# new_data201704/2011 100%[===================>]   1.98G  16.7MB/s    in 2m 2s
#
# 2023-10-13 12:01:24 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/2011.zip’ saved [2128043906/2128043906]
#
# --2023-10-13 12:01:25--  https://www.takakura.com/Kyoto_data/new_data201704/2011/201101.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 363260824 (346M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201101.zip’
#
# new_data201704/2011 100%[===================>] 346.43M  16.4MB/s    in 21s
#
# 2023-10-13 12:01:46 (16.1 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201101.zip’ saved [363260824/363260824]
#
# --2023-10-13 12:01:46--  https://www.takakura.com/Kyoto_data/new_data201704/2011/201102.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 340457179 (325M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201102.zip’
#
# new_data201704/2011 100%[===================>] 324.68M  17.0MB/s    in 20s
#
# 2023-10-13 12:02:06 (16.3 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201102.zip’ saved [340457179/340457179]
#
# --2023-10-13 12:02:06--  https://www.takakura.com/Kyoto_data/new_data201704/2011/201103.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 238476457 (227M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201103.zip’
#
# new_data201704/2011 100%[===================>] 227.43M  16.8MB/s    in 13s
#
# 2023-10-13 12:02:20 (16.9 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201103.zip’ saved [238476457/238476457]
#
# --2023-10-13 12:02:20--  https://www.takakura.com/Kyoto_data/new_data201704/2011/201104.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 80092493 (76M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201104.zip’
#
# new_data201704/2011 100%[===================>]  76.38M  17.4MB/s    in 4.4s
#
# 2023-10-13 12:02:24 (17.5 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201104.zip’ saved [80092493/80092493]
#
# --2023-10-13 12:02:24--  https://www.takakura.com/Kyoto_data/new_data201704/2011/201105.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 102708157 (98M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201105.zip’
#
# new_data201704/2011 100%[===================>]  97.95M  17.0MB/s    in 5.8s
#
# 2023-10-13 12:02:30 (16.9 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201105.zip’ saved [102708157/102708157]
#
# --2023-10-13 12:02:30--  https://www.takakura.com/Kyoto_data/new_data201704/2011/201106.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 108569626 (104M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201106.zip’
#
# new_data201704/2011 100%[===================>] 103.54M  16.5MB/s    in 6.3s
#
# 2023-10-13 12:02:37 (16.4 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201106.zip’ saved [108569626/108569626]
#
# --2023-10-13 12:02:37--  https://www.takakura.com/Kyoto_data/new_data201704/2011/201107.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 75856396 (72M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201107.zip’
#
# new_data201704/2011 100%[===================>]  72.34M  17.0MB/s    in 4.3s
#
# 2023-10-13 12:02:41 (16.9 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201107.zip’ saved [75856396/75856396]
#
# --2023-10-13 12:02:41--  https://www.takakura.com/Kyoto_data/new_data201704/2011/201108.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 103202190 (98M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201108.zip’
#
# new_data201704/2011 100%[===================>]  98.42M  17.2MB/s    in 5.8s
#
# 2023-10-13 12:02:47 (17.0 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201108.zip’ saved [103202190/103202190]
#
# --2023-10-13 12:02:47--  https://www.takakura.com/Kyoto_data/new_data201704/2011/201109.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 172186527 (164M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201109.zip’
#
# new_data201704/2011 100%[===================>] 164.21M  17.0MB/s    in 9.9s
#
# 2023-10-13 12:02:57 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201109.zip’ saved [172186527/172186527]
#
# --2023-10-13 12:02:58--  https://www.takakura.com/Kyoto_data/new_data201704/2011/201110.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 206292395 (197M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201110.zip’
#
# new_data201704/2011 100%[===================>] 196.74M  16.9MB/s    in 12s
#
# 2023-10-13 12:03:09 (16.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201110.zip’ saved [206292395/206292395]
#
# --2023-10-13 12:03:09--  https://www.takakura.com/Kyoto_data/new_data201704/2011/201111.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 152999685 (146M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201111.zip’
#
# new_data201704/2011 100%[===================>] 145.91M  16.9MB/s    in 8.6s
#
# 2023-10-13 12:03:18 (16.9 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201111.zip’ saved [152999685/152999685]
#
# --2023-10-13 12:03:18--  https://www.takakura.com/Kyoto_data/new_data201704/2011/201112.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 183942061 (175M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201112.zip’
#
# new_data201704/2011 100%[===================>] 175.42M  16.7MB/s    in 10s
#
# 2023-10-13 12:03:29 (16.8 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201112.zip’ saved [183942061/183942061]
#
# --2023-10-13 12:03:29--  https://www.takakura.com/Kyoto_data/new_data201704/2012/2012.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1272176489 (1.2G) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/2012.zip’
#
# new_data201704/2012 100%[===================>]   1.18G  17.2MB/s    in 72s
#
# 2023-10-13 12:04:42 (16.8 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/2012.zip’ saved [1272176489/1272176489]
#
# --2023-10-13 12:04:42--  https://www.takakura.com/Kyoto_data/new_data201704/2012/201201.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 172122923 (164M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201201.zip’
#
# new_data201704/2012 100%[===================>] 164.15M  16.1MB/s    in 10s
#
# 2023-10-13 12:04:52 (16.4 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201201.zip’ saved [172122923/172122923]
#
# --2023-10-13 12:04:52--  https://www.takakura.com/Kyoto_data/new_data201704/2012/201202.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 156139806 (149M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201202.zip’
#
# new_data201704/2012 100%[===================>] 148.91M  15.1MB/s    in 9.5s
#
# 2023-10-13 12:05:02 (15.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201202.zip’ saved [156139806/156139806]
#
# --2023-10-13 12:05:02--  https://www.takakura.com/Kyoto_data/new_data201704/2012/201203.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 127145281 (121M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201203.zip’
#
# new_data201704/2012 100%[===================>] 121.25M  16.9MB/s    in 7.1s
#
# 2023-10-13 12:05:09 (17.0 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201203.zip’ saved [127145281/127145281]
#
# --2023-10-13 12:05:09--  https://www.takakura.com/Kyoto_data/new_data201704/2012/201204.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 113916151 (109M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201204.zip’
#
# new_data201704/2012 100%[===================>] 108.64M  17.6MB/s    in 6.3s
#
# 2023-10-13 12:05:15 (17.2 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201204.zip’ saved [113916151/113916151]
#
# --2023-10-13 12:05:15--  https://www.takakura.com/Kyoto_data/new_data201704/2012/201205.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 85410555 (81M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201205.zip’
#
# new_data201704/2012 100%[===================>]  81.45M  16.9MB/s    in 4.7s
#
# 2023-10-13 12:05:20 (17.4 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201205.zip’ saved [85410555/85410555]
#
# --2023-10-13 12:05:20--  https://www.takakura.com/Kyoto_data/new_data201704/2012/201206.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 79104418 (75M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201206.zip’
#
# new_data201704/2012 100%[===================>]  75.44M  17.0MB/s    in 4.4s
#
# 2023-10-13 12:05:25 (17.1 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201206.zip’ saved [79104418/79104418]
#
# --2023-10-13 12:05:25--  https://www.takakura.com/Kyoto_data/new_data201704/2012/201207.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88033544 (84M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201207.zip’
#
# new_data201704/2012 100%[===================>]  83.96M  16.5MB/s    in 5.1s
#
# 2023-10-13 12:05:30 (16.5 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201207.zip’ saved [88033544/88033544]
#
# --2023-10-13 12:05:30--  https://www.takakura.com/Kyoto_data/new_data201704/2012/201208.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91966710 (88M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201208.zip’
#
# new_data201704/2012 100%[===================>]  87.71M  17.2MB/s    in 6.4s
#
# 2023-10-13 12:05:37 (13.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201208.zip’ saved [91966710/91966710]
#
# --2023-10-13 12:05:37--  https://www.takakura.com/Kyoto_data/new_data201704/2012/201209.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 82474175 (79M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201209.zip’
#
# new_data201704/2012 100%[===================>]  78.65M  16.7MB/s    in 4.7s
#
# 2023-10-13 12:05:42 (16.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201209.zip’ saved [82474175/82474175]
#
# --2023-10-13 12:05:42--  https://www.takakura.com/Kyoto_data/new_data201704/2012/201210.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 97135638 (93M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201210.zip’
#
# new_data201704/2012 100%[===================>]  92.64M  16.9MB/s    in 5.5s
#
# 2023-10-13 12:05:47 (16.8 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201210.zip’ saved [97135638/97135638]
#
# --2023-10-13 12:05:47--  https://www.takakura.com/Kyoto_data/new_data201704/2012/201211.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 87457392 (83M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201211.zip’
#
# new_data201704/2012 100%[===================>]  83.41M  17.3MB/s    in 4.8s
#
# 2023-10-13 12:05:52 (17.3 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201211.zip’ saved [87457392/87457392]
#
# --2023-10-13 12:05:52--  https://www.takakura.com/Kyoto_data/new_data201704/2012/201212.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91269980 (87M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201212.zip’
#
# new_data201704/2012 100%[===================>]  87.04M  17.2MB/s    in 5.1s
#
# 2023-10-13 12:05:58 (17.1 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201212.zip’ saved [91269980/91269980]
#
# --2023-10-13 12:05:58--  https://www.takakura.com/Kyoto_data/new_data201704/2013/2013.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2144402145 (2.0G) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/2013.zip’
#
# new_data201704/2013 100%[===================>]   2.00G  16.2MB/s    in 2m 3s
#
# 2023-10-13 12:08:01 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/2013.zip’ saved [2144402145/2144402145]
#
# --2023-10-13 12:08:01--  https://www.takakura.com/Kyoto_data/new_data201704/2013/201301.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 97193065 (93M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201301.zip’
#
# new_data201704/2013 100%[===================>]  92.69M  16.9MB/s    in 5.5s
#
# 2023-10-13 12:08:07 (16.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201301.zip’ saved [97193065/97193065]
#
# --2023-10-13 12:08:07--  https://www.takakura.com/Kyoto_data/new_data201704/2013/201302.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 110104426 (105M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201302.zip’
#
# new_data201704/2013 100%[===================>] 105.00M  15.8MB/s    in 6.6s
#
# 2023-10-13 12:08:14 (16.0 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201302.zip’ saved [110104426/110104426]
#
# --2023-10-13 12:08:14--  https://www.takakura.com/Kyoto_data/new_data201704/2013/201303.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 106071605 (101M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201303.zip’
#
# new_data201704/2013 100%[===================>] 101.16M  16.1MB/s    in 6.6s
#
# 2023-10-13 12:08:21 (15.4 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201303.zip’ saved [106071605/106071605]
#
# --2023-10-13 12:08:21--  https://www.takakura.com/Kyoto_data/new_data201704/2013/201304.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 123743211 (118M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201304.zip’
#
# new_data201704/2013 100%[===================>] 118.01M  16.6MB/s    in 7.2s
#
# 2023-10-13 12:08:28 (16.3 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201304.zip’ saved [123743211/123743211]
#
# --2023-10-13 12:08:28--  https://www.takakura.com/Kyoto_data/new_data201704/2013/201305.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 163750259 (156M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201305.zip’
#
# new_data201704/2013 100%[===================>] 156.16M  16.8MB/s    in 9.9s
#
# 2023-10-13 12:08:38 (15.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201305.zip’ saved [163750259/163750259]
#
# --2023-10-13 12:08:38--  https://www.takakura.com/Kyoto_data/new_data201704/2013/201306.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 252954149 (241M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201306.zip’
#
# new_data201704/2013 100%[===================>] 241.24M  16.8MB/s    in 14s
#
# 2023-10-13 12:08:53 (16.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201306.zip’ saved [252954149/252954149]
#
# --2023-10-13 12:08:53--  https://www.takakura.com/Kyoto_data/new_data201704/2013/201307.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 284647725 (271M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201307.zip’
#
# new_data201704/2013 100%[===================>] 271.46M  16.8MB/s    in 16s
#
# 2023-10-13 12:09:09 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201307.zip’ saved [284647725/284647725]
#
# --2023-10-13 12:09:09--  https://www.takakura.com/Kyoto_data/new_data201704/2013/201308.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 246479156 (235M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201308.zip’
#
# new_data201704/2013 100%[===================>] 235.06M  16.3MB/s    in 14s
#
# 2023-10-13 12:09:24 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201308.zip’ saved [246479156/246479156]
#
# --2023-10-13 12:09:24--  https://www.takakura.com/Kyoto_data/new_data201704/2013/201309.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 184247501 (176M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201309.zip’
#
# new_data201704/2013 100%[===================>] 175.71M  16.8MB/s    in 11s
#
# 2023-10-13 12:09:34 (16.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201309.zip’ saved [184247501/184247501]
#
# --2023-10-13 12:09:34--  https://www.takakura.com/Kyoto_data/new_data201704/2013/201310.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 163210187 (156M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201310.zip’
#
# new_data201704/2013 100%[===================>] 155.65M  16.6MB/s    in 9.3s
#
# 2023-10-13 12:09:44 (16.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201310.zip’ saved [163210187/163210187]
#
# --2023-10-13 12:09:44--  https://www.takakura.com/Kyoto_data/new_data201704/2013/201311.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 228164774 (218M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201311.zip’
#
# new_data201704/2013 100%[===================>] 217.59M  16.3MB/s    in 13s
#
# 2023-10-13 12:09:57 (16.5 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201311.zip’ saved [228164774/228164774]
#
# --2023-10-13 12:09:57--  https://www.takakura.com/Kyoto_data/new_data201704/2013/201312.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 183836171 (175M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201312.zip’
#
# new_data201704/2013 100%[===================>] 175.32M  16.3MB/s    in 11s
#
# 2023-10-13 12:10:08 (16.5 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201312.zip’ saved [183836171/183836171]
#
# --2023-10-13 12:10:08--  https://www.takakura.com/Kyoto_data/new_data201704/2014/2014.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2381169043 (2.2G) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/2014.zip’
#
# new_data201704/2014 100%[===================>]   2.22G  16.6MB/s    in 2m 17s
#
# 2023-10-13 12:12:25 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/2014.zip’ saved [2381169043/2381169043]
#
# --2023-10-13 12:12:25--  https://www.takakura.com/Kyoto_data/new_data201704/2014/201401.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 181678933 (173M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201401.zip’
#
# new_data201704/2014 100%[===================>] 173.26M  16.7MB/s    in 10s
#
# 2023-10-13 12:12:36 (16.5 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201401.zip’ saved [181678933/181678933]
#
# --2023-10-13 12:12:36--  https://www.takakura.com/Kyoto_data/new_data201704/2014/201402.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 194307009 (185M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201402.zip’
#
# new_data201704/2014 100%[===================>] 185.30M  15.2MB/s    in 12s
#
# 2023-10-13 12:12:48 (15.9 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201402.zip’ saved [194307009/194307009]
#
# --2023-10-13 12:12:48--  https://www.takakura.com/Kyoto_data/new_data201704/2014/201403.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 237737582 (227M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201403.zip’
#
# new_data201704/2014 100%[===================>] 226.72M  16.3MB/s    in 15s
#
# 2023-10-13 12:13:03 (15.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201403.zip’ saved [237737582/237737582]
#
# --2023-10-13 12:13:03--  https://www.takakura.com/Kyoto_data/new_data201704/2014/201404.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 222666361 (212M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201404.zip’
#
# new_data201704/2014 100%[===================>] 212.35M  16.6MB/s    in 13s
#
# 2023-10-13 12:13:16 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201404.zip’ saved [222666361/222666361]
#
# --2023-10-13 12:13:16--  https://www.takakura.com/Kyoto_data/new_data201704/2014/201405.zip
# Connecting to www.takakura.com (www.takakura.com)|150.100.120.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 223946714 (214M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201405.zip’
#
# new_data201704/2014 100%[===================>] 213.57M  16.1MB/s    in 14s
#
# 2023-10-13 12:13:30 (15.2 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201405.zip’ saved [223946714/223946714]
#
# --2023-10-13 12:13:30--  https://www.takakura.com/Kyoto_data/new_data201704/2014/201406.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 202883008 (193M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201406.zip’
#
# new_data201704/2014 100%[===================>] 193.48M  16.7MB/s    in 12s
#
# 2023-10-13 12:13:42 (16.5 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201406.zip’ saved [202883008/202883008]
#
# --2023-10-13 12:13:42--  https://www.takakura.com/Kyoto_data/new_data201704/2014/201407.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 197720145 (189M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201407.zip’
#
# new_data201704/2014 100%[===================>] 188.56M  16.7MB/s    in 11s
#
# 2023-10-13 12:13:54 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201407.zip’ saved [197720145/197720145]
#
# --2023-10-13 12:13:54--  https://www.takakura.com/Kyoto_data/new_data201704/2014/201408.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 126973571 (121M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201408.zip’
#
# new_data201704/2014 100%[===================>] 121.09M  16.0MB/s    in 7.4s
#
# 2023-10-13 12:14:01 (16.4 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201408.zip’ saved [126973571/126973571]
#
# --2023-10-13 12:14:01--  https://www.takakura.com/Kyoto_data/new_data201704/2014/201409.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 127738413 (122M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201409.zip’
#
# new_data201704/2014 100%[===================>] 121.82M  16.5MB/s    in 7.3s
#
# 2023-10-13 12:14:09 (16.8 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201409.zip’ saved [127738413/127738413]
#
# --2023-10-13 12:14:09--  https://www.takakura.com/Kyoto_data/new_data201704/2014/201410.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 213758634 (204M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201410.zip’
#
# new_data201704/2014 100%[===================>] 203.86M  17.4MB/s    in 12s
#
# 2023-10-13 12:14:21 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201410.zip’ saved [213758634/213758634]
#
# --2023-10-13 12:14:21--  https://www.takakura.com/Kyoto_data/new_data201704/2014/201411.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 237687723 (227M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201411.zip’
#
# new_data201704/2014 100%[===================>] 226.68M  16.2MB/s    in 14s
#
# 2023-10-13 12:14:35 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201411.zip’ saved [237687723/237687723]
#
# --2023-10-13 12:14:35--  https://www.takakura.com/Kyoto_data/new_data201704/2014/201412.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 214071034 (204M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201412.zip’
#
# new_data201704/2014 100%[===================>] 204.15M  17.4MB/s    in 12s
#
# 2023-10-13 12:14:48 (16.8 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201412.zip’ saved [214071034/214071034]
#
# --2023-10-13 12:14:48--  https://www.takakura.com/Kyoto_data/new_data201704/2015/2015.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2645110668 (2.5G) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/2015.zip’
#
# new_data201704/2015 100%[===================>]   2.46G  16.7MB/s    in 2m 30s
#
# 2023-10-13 12:17:18 (16.8 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/2015.zip’ saved [2645110668/2645110668]
#
# --2023-10-13 12:17:19--  https://www.takakura.com/Kyoto_data/new_data201704/2015/201501.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 249257072 (238M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201501.zip’
#
# new_data201704/2015 100%[===================>] 237.71M  14.1MB/s    in 15s
#
# 2023-10-13 12:17:34 (16.0 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201501.zip’ saved [249257072/249257072]
#
# --2023-10-13 12:17:34--  https://www.takakura.com/Kyoto_data/new_data201704/2015/201502.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 165032061 (157M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201502.zip’
#
# new_data201704/2015 100%[===================>] 157.39M  14.2MB/s    in 10s
#
# 2023-10-13 12:17:44 (15.0 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201502.zip’ saved [165032061/165032061]
#
# --2023-10-13 12:17:44--  https://www.takakura.com/Kyoto_data/new_data201704/2015/201503.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 389166376 (371M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201503.zip’
#
# new_data201704/2015 100%[===================>] 371.14M  16.2MB/s    in 23s
#
# 2023-10-13 12:18:08 (15.8 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201503.zip’ saved [389166376/389166376]
#
# --2023-10-13 12:18:08--  https://www.takakura.com/Kyoto_data/new_data201704/2015/201504.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 215105453 (205M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201504.zip’
#
# new_data201704/2015 100%[===================>] 205.14M  16.1MB/s    in 12s
#
# 2023-10-13 12:18:20 (16.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201504.zip’ saved [215105453/215105453]
#
# --2023-10-13 12:18:21--  https://www.takakura.com/Kyoto_data/new_data201704/2015/201505.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 229783909 (219M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201505.zip’
#
# new_data201704/2015 100%[===================>] 219.14M  16.7MB/s    in 13s
#
# 2023-10-13 12:18:34 (16.3 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201505.zip’ saved [229783909/229783909]
#
# --2023-10-13 12:18:34--  https://www.takakura.com/Kyoto_data/new_data201704/2015/201506.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 206850329 (197M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201506.zip’
#
# new_data201704/2015 100%[===================>] 197.27M  16.5MB/s    in 12s
#
# 2023-10-13 12:18:46 (16.5 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201506.zip’ saved [206850329/206850329]
#
# --2023-10-13 12:18:46--  https://www.takakura.com/Kyoto_data/new_data201704/2015/201507.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 204662094 (195M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201507.zip’
#
# new_data201704/2015 100%[===================>] 195.18M  17.2MB/s    in 12s
#
# 2023-10-13 12:18:58 (16.9 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201507.zip’ saved [204662094/204662094]
#
# --2023-10-13 12:18:58--  https://www.takakura.com/Kyoto_data/new_data201704/2015/201508.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 236324314 (225M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201508.zip’
#
# new_data201704/2015 100%[===================>] 225.38M  16.8MB/s    in 14s
#
# 2023-10-13 12:19:12 (16.7 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201508.zip’ saved [236324314/236324314]
#
# --2023-10-13 12:19:12--  https://www.takakura.com/Kyoto_data/new_data201704/2015/201509.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 181064307 (173M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201509.zip’
#
# new_data201704/2015 100%[===================>] 172.68M  16.7MB/s    in 10s
#
# 2023-10-13 12:19:22 (16.6 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201509.zip’ saved [181064307/181064307]
#
# --2023-10-13 12:19:22--  https://www.takakura.com/Kyoto_data/new_data201704/2015/201510.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 170174211 (162M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201510.zip’
#
# new_data201704/2015 100%[===================>] 162.29M  17.3MB/s    in 9.5s
#
# 2023-10-13 12:19:32 (17.0 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201510.zip’ saved [170174211/170174211]
#
# --2023-10-13 12:19:32--  https://www.takakura.com/Kyoto_data/new_data201704/2015/201511.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 216323865 (206M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201511.zip’
#
# new_data201704/2015 100%[===================>] 206.30M  17.0MB/s    in 13s
#
# 2023-10-13 12:19:45 (16.4 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201511.zip’ saved [216323865/216323865]
#
# --2023-10-13 12:19:45--  https://www.takakura.com/Kyoto_data/new_data201704/2015/201512.zip
# Reusing existing connection to www.takakura.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 181366761 (173M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201512.zip’
#
# new_data201704/2015 100%[===================>] 172.96M  16.6MB/s    in 10s
#
# 2023-10-13 12:19:55 (16.5 MB/s) - ‘/content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201512.zip’ saved [181366761/181366761]
#
# FINISHED --2023-10-13 12:19:55--
# Total wall clock time: 38m 18s
# Downloaded: 121 files, 37G in 37m 51s (16.5 MB/s)

# %%
# !ls -ahl '/content/drive/MyDrive/Kyoto2006+'
# Out:
# total 4.0K
# drwx------ 2 root root 4.0K Oct 13 11:41 new_data201704

# %%
# !find '/content/drive/MyDrive/Kyoto2006+/new_data201704/' -type f  -name "*.zip"
# Out:
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2006/2006.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2006/200611.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2006/200612.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2007/2007.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200701.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200702.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200703.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200704.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200705.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200706.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200707.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200708.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200709.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200710.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200711.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2007/200712.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2008/2008.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200801.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200802.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200803.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200804.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200805.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200806.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200807.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200808.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200809.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200810.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200811.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2008/200812.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2009/2009.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200901.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200902.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200903.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200904.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200905.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200906.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200907.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200908.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200909.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200910.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200911.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2009/200912.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2010/2010.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201001.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201002.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201003.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201004.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201005.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201006.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201007.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201008.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201009.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201010.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201011.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2010/201012.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2011/2011.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201101.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201102.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201103.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201104.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201105.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201106.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201107.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201108.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201109.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201110.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201111.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2011/201112.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2012/2012.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201201.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201202.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201203.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201204.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201205.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201206.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201207.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201208.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201209.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201210.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201211.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2012/201212.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2013/2013.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201301.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201302.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201303.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201304.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201305.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201306.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201307.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201308.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201309.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201310.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201311.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2013/201312.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2014/2014.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201401.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201402.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201403.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201404.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201405.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201406.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201407.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201408.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201409.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201410.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201411.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2014/201412.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2015/2015.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201501.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201502.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201503.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201504.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201505.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201506.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201507.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201508.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201509.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201510.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201511.zip
# /content/drive/MyDrive/Kyoto2006+/new_data201704/2015/201512.zip

# %%
import os
import zipfile
import shutil

# Function to extract all TXT files from ZIP archives
def extract_txt_files_from_zips(source_folder, target_folder):
    for root, _, files in os.walk(source_folder):
        for file in files:
            if file.endswith(".zip"):
                zip_path = os.path.join(root, file)
                print(zip_path)
                with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                    for member in zip_ref.infolist():
                        if member.filename.endswith(".txt"):
                            txt_file_data = zip_ref.read(member.filename)
                            txt_file_path = os.path.join(target_folder, os.path.basename(member.filename))
                            with open(txt_file_path, 'wb') as txt_file:
                                txt_file.write(txt_file_data)
                                print(txt_file_path)

source_folder = '/content/drive/MyDrive/Kyoto2006+/new_data201704'
target_folder = '/content/drive/MyDrive/Kyoto2006+/extracted'

# Ensure the target folder exists
if not os.path.exists(target_folder):
    os.makedirs(target_folder)

# Call the function to extract and flatten the TXT files
extract_txt_files_from_zips(source_folder, target_folder)

print("Extraction and flattening completed.")

# %%
# !head /content/drive/MyDrive/Kyoto2006+/extracted/20061101.txt
# Out:
# 27.561208	smtp	3179	175	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	SF	0	0	0	1	fda2:69aa:1f1a:84b0:130d:2736:3fa0:42da	2161	fda2:69aa:1f1a:61a4:7dc5:27f2:0713:0f0e	25	00:00:09	tcp
# 0.000000	other	0	0	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	S0	0	0	0	-1	fda2:69aa:1f1a:0104:3fff:571a:ff2c:00a5	138	fda2:69aa:1f1a:2108:3f84:570e:ffe4:007b	138	00:00:14	udp
# 86366.249616	other	244776	0	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	S0	0	0	0	-1	fda2:69aa:1f1a:540c:7d80:2750:07a6:28a5	32770	fda2:69aa:1f1a:0d61:1001:01e2:02fb:2a22	8649	00:00:15	udp
# 2994.374758	other	15744	18154	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	RSTOS0	0	0	0	-1	fda2:69aa:1f1a:3aef:7af3:3027:3045:7ff2	1400	fda2:69aa:1f1a:e714:277f:10e1:03f2:425a	80	00:00:16	tcp
# 4.749378	smtp	7895	244	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	SF	0	0	0	1	fda2:69aa:1f1a:381e:25aa:0bff:12e8:0365	1806	fda2:69aa:1f1a:61a4:7dc5:27f2:0713:0f0e	25	00:00:17	tcp
# 10358.914673	other	2932	3500	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	SF	0	0	0	-1	fda2:69aa:1f1a:2c7e:7a23:304a:30ba:01e5	1723	fda2:69aa:1f1a:a5ae:280f:0a54:74d8:1521	1060	00:00:46	tcp
# 2764.673397	other	95300	37891	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	SF	0	0	0	-1	fda2:69aa:1f1a:3aef:7af3:3027:3045:7ff2	1160	fda2:69aa:1f1a:1abc:2746:104f:2b03:03db	80	00:00:47	tcp
# 66709.336541	other	1	0	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	RSTRH	0	0	0	-1	fda2:69aa:1f1a:1ec2:7dc8:276f:0fbc:1529	445	fda2:69aa:1f1a:5d5e:7dde:086d:5c76:14cb	4537	00:01:45	tcp
# 31.826613	other	550	0	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	SF	0	0	0	-1	fda2:69aa:1f1a:691a:7db6:27cd:0f23:127c	36120	fda2:69aa:1f1a:5dff:23d8:23de:0050:3dd8	59879	00:03:10	tcp
# 0.000000	other	0	0	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	S0	20081(1)	0	60(1)	-1	fda2:69aa:1f1a:ef2c:35cf:311b:029d:098e	1210	fda2:69aa:1f1a:3aef:7af3:3027:3045:7ff2	1434	00:03:38	udp

# %%
# Count the resulting dataset files
# !ls /content/drive/MyDrive/Kyoto2006+/extracted/ | wc -l
# Out:
# 3257

# %%
# Size of the entire Kyoto2006+ dataset
# !du -sh /content/drive/MyDrive/Kyoto2006+/extracted/
# Out:
# 126G	/content/drive/MyDrive/Kyoto2006+/extracted/

# %%
# %%bash
#
# # Define the column names
# column_names=("Duration" "Service" "Source bytes" "Destination bytes" "Count" \
#               "Same srv rate" "Serror rate" "Srv serror rate" "Dst host count" \
#               "Dst host srv count" "Dst host same src port rate" "Dst host serror rate" \
#               "Dst host srv serror rate" "Flag" "IDS detection" "Malware detection" \
#               "Ashula detection" "Label" "Source IP Address" "Source Port Number" \
#               "Destination IP Address" "Destination Port Number" "Start Time" "Protocol")
#
# # Convert the column names array to a space-separated string
# header_text=$(IFS=" "; echo "${column_names[*]}")
#
# # Create the header file
# echo "$header_text" > header.txt
#
# # Print a message to indicate the header file is created
# echo "Header file 'header.txt' is created."
#
# cat header.txt
# Out:
# Header file 'header.txt' is created.
# Duration Service Source bytes Destination bytes Count Same srv rate Serror rate Srv serror rate Dst host count Dst host srv count Dst host same src port rate Dst host serror rate Dst host srv serror rate Flag IDS detection Malware detection Ashula detection Label Source IP Address Source Port Number Destination IP Address Destination Port Number Start Time Protocol

# %%
# %%bash
#
# # Specify the source directory where the files are located
# source_dir="/content/drive/MyDrive/Kyoto2006+/extracted/"
#
# # Specify the destination directory where concatenated files will be saved
# destination_dir="concatenated/"
#
# # Create the destination directory if it doesn't exist
# mkdir -p "$destination_dir"
#
# # Loop through the years
# for year in {2006..2015}; do
#     # Use a wildcard to select files for the current year
#     files_for_year="$source_dir/$year*.txt"
#
#     # Concatenate files for the current year and save to destination directory
#     cat $files_for_year > "${destination_dir}${year}_concatenated.txt"
#
#     # Print a message to indicate the concatenation is completed for the year
#     echo "Concatenation completed for $year"
# done
#
# # Print a final message
# echo "All concatenations completed."
# Out:
# Concatenation completed for 2006
# Concatenation completed for 2007
# Concatenation completed for 2008
# Concatenation completed for 2009
# Concatenation completed for 2010
# Concatenation completed for 2011
# Concatenation completed for 2012
# Concatenation completed for 2013
# Concatenation completed for 2014
# Concatenation completed for 2015
# All concatenations completed.

# %%
# !ls /content/concatenated -ahl
# Out:
# total 126G
# drwxr-xr-x 2 root root 4.0K Oct 14 07:58 .
# drwxr-xr-x 1 root root 4.0K Oct 14 06:54 ..
# -rw-r--r-- 1 root root 683M Oct 14 06:54 2006_concatenated.txt
# -rw-r--r-- 1 root root 4.3G Oct 14 07:00 2007_concatenated.txt
# -rw-r--r-- 1 root root 6.9G Oct 14 07:06 2008_concatenated.txt
# -rw-r--r-- 1 root root  14G Oct 14 07:14 2009_concatenated.txt
# -rw-r--r-- 1 root root  28G Oct 14 07:25 2010_concatenated.txt
# -rw-r--r-- 1 root root  14G Oct 14 07:33 2011_concatenated.txt
# -rw-r--r-- 1 root root 8.1G Oct 14 07:40 2012_concatenated.txt
# -rw-r--r-- 1 root root  15G Oct 14 07:49 2013_concatenated.txt
# -rw-r--r-- 1 root root  18G Oct 14 07:58 2014_concatenated.txt
# -rw-r--r-- 1 root root  19G Oct 14 08:07 2015_concatenated.txt

# %%
# !head /content/concatenated/2015_concatenated.txt
# Out:
# 0.000000	dhcp	0	0	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	S0	0	0	0	-1	fd0e:9e00:6814:170a:4341:33f8:2fa1:0cf2	59619	fd0e:9e00:6814:71a4:7d24:27c6:60ef:310c	67	17:51:17	udp
# 0.000000	dhcp	0	0	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	S0	0	0	0	-1	fd0e:9e00:6814:170a:4341:33f8:2fa1:0cf2	59619	fd0e:9e00:6814:c1fd:7d27:27a7:601e:21fe	67	00:16:12	udp
# 0.000000	dhcp	0	0	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	S0	0	0	0	-1	fd0e:9e00:6814:170a:4341:33f8:2fa1:0cf2	59619	fd0e:9e00:6814:d7ee:7ded:27d9:0fbc:15f7	67	10:52:21	udp
# 0.000000	dhcp	0	0	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	S0	0	0	0	-1	fd0e:9e00:6814:2598:39c5:0fc6:2dbe:1b7e	59619	fd0e:9e00:6814:0681:7dec:2773:605d:1b1c	67	12:41:33	udp
# 0.000000	dhcp	0	0	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	S0	0	0	0	-1	fd0e:9e00:6814:2598:39c5:0fc6:2dbe:1b7e	59619	fd0e:9e00:6814:0a6e:7ddb:27b6:60eb:5941	67	13:19:07	udp
# 0.000000	dhcp	0	0	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	S0	0	0	0	-1	fd0e:9e00:6814:2598:39c5:0fc6:2dbe:1b7e	59619	fd0e:9e00:6814:149f:7d8a:273f:60cc:0858	67	20:10:35	udp
# 0.000000	dhcp	0	0	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	S0	0	0	0	-1	fd0e:9e00:6814:2598:39c5:0fc6:2dbe:1b7e	59619	fd0e:9e00:6814:15cf:7d96:278a:61c2:2a62	67	22:16:51	udp
# 0.000000	dhcp	0	0	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	S0	0	0	0	-1	fd0e:9e00:6814:2598:39c5:0fc6:2dbe:1b7e	59619	fd0e:9e00:6814:237d:7dc4:276d:604f:0c0d	67	18:54:31	udp
# 0.000000	dhcp	0	0	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	S0	0	0	0	-1	fd0e:9e00:6814:2598:39c5:0fc6:2dbe:1b7e	59619	fd0e:9e00:6814:30ea:7dc4:2782:6001:773b	67	13:07:05	udp
# 0.000000	dhcp	0	0	0	0.00	0.00	0.00	0	0	0.00	0.00	0.00	S0	0	0	0	-1	fd0e:9e00:6814:2598:39c5:0fc6:2dbe:1b7e	59619	fd0e:9e00:6814:3de3:7d02:270e:6017:4ec3	67	12:45:37	udp

# %%
# !cp /content/concatenated/2015_concatenated.txt /content/drive/MyDrive/Kyoto2006+/2015_concatenated.txt

# %% [markdown]
# ### Preprocessing of the Kyoto 2015 dataset

# %%
# !wc -l /content/concatenated/2015_concatenated.txt
# Out:
# 115574748 /content/concatenated/2015_concatenated.txt

# %%
# !cut -f 18 -d $'\t' /content/concatenated/2015_concatenated.txt | sort | uniq
# Out:
# -1
# 1
# -2

# %%
import pandas as pd
import warnings
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
import gc

# Ignore all warnings
warnings.filterwarnings("ignore")

# Specify the path to your large text file
file_path = '/content/drive/MyDrive/Kyoto2006+/2015_concatenated.txt'

# Define the column names if needed
column_names = ['Duration', 'Service', 'Source bytes', 'Destination bytes', 'Count',
                'Same srv rate', 'Serror rate', 'Srv serror rate', 'Dst host count',
                'Dst host srv count', 'Dst host same src port rate', 'Dst host serror rate',
                'Dst host srv serror rate', 'Flag', 'IDS detection', 'Malware detection',
                'Ashula detection', 'Label', 'Source IP Address', 'Source Port Number',
                'Destination IP Address', 'Destination Port Number', 'Start Time', 'Protocol']

# Define the chunk size (adjust this based on your available memory)
chunk_size = 10000000  # 10 million rows per chunk, you can increase or decrease this value

i = 0

# Define a custom function to map values to 1 if non-zero, otherwise to 0
def map_to_binary(value):
    if value == '0':
        return 0
    else:
        return 1

# Mapping function to convert labels
def map_label(label):
    if label == 1:
        return 0  # Normal
    else:
        return 1  # Attack

# Initialize an empty DataFrame for the final results
df = pd.DataFrame(columns=column_names)

# Open the file and read it in chunks
for chunk in pd.read_csv(file_path, sep='\t', header=None, names=column_names, chunksize=chunk_size):

    #display(chunk.head)

    # Check memory usage and perform sampling if memory is almost full
    mem_usage = chunk.memory_usage(deep=True).sum() / (1024**2)  # in MB
    if mem_usage < 47000:  # memory threshold, adjust as needed

      # Print the chunk number
      i += 1
      print("Processing chunk", i)

      # Process each chunk as needed

      """# Step 1: Handling Missing Values
      # This step can be skipped, as the dataset does not have missing values or NaN

      # Check for missing values, NAN
      check_nan = chunk.isna().sum().sum()

      # Check if missing values are represented as empty values (",,")
      missing_values_as_empty = chunk.applymap(lambda x: x == '')

      # Count the number of missing values in each column
      missing_values_count = missing_values_as_empty.sum()

      # Check if all elements in the missing_values_count Series are different from 0
      check_null = (missing_values_count != 0).all()

      # Replace empty values with NaN
      if (check_null):
        chunk.replace("", np.nan, inplace=True)

      # Impute missing values with the most frequent value for categorical columns and mean for numerical columns
      if (check_null or check_nan !=0):
        imputer = SimpleImputer(strategy='most_frequent', missing_values=pd.NA)
        for col in chunk.columns:
          if chunk[col].dtype == 'object':
            chunk[col] = imputer.fit_transform(df[[col]])
          else:
            chunk[col] = chunk[col].fillna(chunk[col].mean())"""

      # Check again for missing values, NAN
      display(chunk.isna().sum(axis=0))

      # Check chunk info
      #display(chunk.info())

      # 2 # Encode Categorical Features and Label

      # Apply the custom encoding to columns 15, 16, and 17. 0 - no detection / 1 - alert
      chunk['IDS detection'] = chunk['IDS detection'].apply(map_to_binary)
      chunk['Malware detection'] = chunk['Malware detection'].apply(map_to_binary)
      chunk['Ashula detection'] = chunk['Ashula detection'].apply(map_to_binary)

      chunk['IDS detection'] = chunk['IDS detection'].astype(int)
      chunk['Malware detection'] = chunk['Malware detection'].astype(int)
      chunk['Ashula detection'] = chunk['Ashula detection'].astype(int)

      print(chunk['IDS detection'].unique())
      print(chunk['Malware detection'].unique())
      print(chunk['Ashula detection'].unique())

      # Before applying map_label
      print("Type of 'Label' column:", chunk['Label'].dtype)
      print("Unique values in 'Label' column before mapping:")
      print(chunk['Label'].unique())

      # Apply the mapping function to the 'Label' column
      chunk['Label'] = chunk['Label'].apply(map_label)
      chunk['Label'] = chunk['Label'].astype(int)

      # After applying map_label
      print("Type of 'Label' column after mapping:", chunk['Label'].dtype)
      print("Unique values in 'Label' column after mapping:")
      print(chunk['Label'].unique())

      categorical_columns = [col for col in chunk.columns if chunk[col].dtype == 'object']
      label_encoder = LabelEncoder()
      for col in categorical_columns:
          try:
              chunk[col] = label_encoder.fit_transform(chunk[col])
          except:
              display(chunk[col])

      # 3 # Normalization (Min-Max Scaling)
      numeric_columns = chunk.select_dtypes(exclude=['object']).columns
      scaler = MinMaxScaler()
      chunk[numeric_columns] = scaler.fit_transform(chunk[numeric_columns])

      """# 4 # Removing duplicate records
      # This step can be skipped, as we already removed duplicated rows during unzip and concatenation in previous section

      # Print the shape of the chunks
      display(chunk.shape)

      # Remove duplicate rows from the chunk while resetting the index
      chunk = chunk.drop_duplicates()
      chunk.reset_index(inplace=True, drop=True)

      if i % 2 == 0:
        print("Shape of previous df")
        display(df.shape)
        # Remove duplicate rows from the chunk while resetting the index
        df = df.drop_duplicates()
        df.reset_index(inplace=True, drop=True)
        print("New shape of df")
        display(df.shape)

      # Print the shape of the chunks
      display(chunk.shape)"""

      # Append the processed chunk to the main DataFrame
      df = pd.concat([df, chunk], ignore_index=True)
      gc.collect()
# Out:
# Processing chunk 1
# Duration                       0
# Service                        0
# Source bytes                   0
# Destination bytes              0
# Count                          0
# Same srv rate                  0
# Serror rate                    0
# Srv serror rate                0
# Dst host count                 0
# Dst host srv count             0
# Dst host same src port rate    0
# Dst host serror rate           0
# Dst host srv serror rate       0
# Flag                           0
# IDS detection                  0
# Malware detection              0
# Ashula detection               0
# Label                          0
# Source IP Address              0
# Source Port Number             0
# Destination IP Address         0
# Destination Port Number        0
# Start Time                     0
# Protocol                       0
# dtype: int64
# [1 0]
# [1 0]
# [1 0]
# Type of 'Label' column: int64
# Unique values in 'Label' column before mapping:
# [-1  1 -2]
# Type of 'Label' column after mapping: int64
# Unique values in 'Label' column after mapping:
# [1 0]
# Processing chunk 2
# Duration                       0
# Service                        0
# Source bytes                   0
# Destination bytes              0
# Count                          0
# Same srv rate                  0
# Serror rate                    0
# Srv serror rate                0
# Dst host count                 0
# Dst host srv count             0
# Dst host same src port rate    0
# Dst host serror rate           0
# Dst host srv serror rate       0
# Flag                           0
# IDS detection                  0
# Malware detection              0
# Ashula detection               0
# Label                          0
# Source IP Address              0
# Source Port Number             0
# Destination IP Address         0
# Destination Port Number        0
# Start Time                     0
# Protocol                       0
# dtype: int64
# [1 0]
# [1 0]
# [1 0]
# Type of 'Label' column: int64
# Unique values in 'Label' column before mapping:
# [-1  1 -2]
# Type of 'Label' column after mapping: int64
# Unique values in 'Label' column after mapping:
# [1 0]
# Processing chunk 3
# Duration                       0
# Service                        0
# Source bytes                   0
# Destination bytes              0
# Count                          0
# Same srv rate                  0
# Serror rate                    0
# Srv serror rate                0
# Dst host count                 0
# Dst host srv count             0
# Dst host same src port rate    0
# Dst host serror rate           0
# Dst host srv serror rate       0
# Flag                           0
# IDS detection                  0
# Malware detection              0
# Ashula detection               0
# Label                          0
# Source IP Address              0
# Source Port Number             0
# Destination IP Address         0
# Destination Port Number        0
# Start Time                     0
# Protocol                       0
# dtype: int64
# [1 0]
# [1 0]
# [1 0]
# Type of 'Label' column: int64
# Unique values in 'Label' column before mapping:
# [-1  1]
# Type of 'Label' column after mapping: int64
# Unique values in 'Label' column after mapping:
# [1 0]
# Processing chunk 4
# Duration                       0
# Service                        0
# Source bytes                   0
# Destination bytes              0
# Count                          0
# Same srv rate                  0
# Serror rate                    0
# Srv serror rate                0
# Dst host count                 0
# Dst host srv count             0
# Dst host same src port rate    0
# Dst host serror rate           0
# Dst host srv serror rate       0
# Flag                           0
# IDS detection                  0
# Malware detection              0
# Ashula detection               0
# Label                          0
# Source IP Address              0
# Source Port Number             0
# Destination IP Address         0
# Destination Port Number        0
# Start Time                     0
# Protocol                       0
# dtype: int64
# [1 0]
# [1 0]
# [1 0]
# Type of 'Label' column: int64
# Unique values in 'Label' column before mapping:
# [-1  1 -2]
# Type of 'Label' column after mapping: int64
# Unique values in 'Label' column after mapping:
# [1 0]
# Processing chunk 5
# Duration                       0
# Service                        0
# Source bytes                   0
# Destination bytes              0
# Count                          0
# Same srv rate                  0
# Serror rate                    0
# Srv serror rate                0
# Dst host count                 0
# Dst host srv count             0
# Dst host same src port rate    0
# Dst host serror rate           0
# Dst host srv serror rate       0
# Flag                           0
# IDS detection                  0
# Malware detection              0
# Ashula detection               0
# Label                          0
# Source IP Address              0
# Source Port Number             0
# Destination IP Address         0
# Destination Port Number        0
# Start Time                     0
# Protocol                       0
# dtype: int64
# [0 1]
# [0 1]
# [1 0]
# Type of 'Label' column: int64
# Unique values in 'Label' column before mapping:
# [-1  1 -2]
# Type of 'Label' column after mapping: int64
# Unique values in 'Label' column after mapping:
# [1 0]
# Processing chunk 6
# Duration                       0
# Service                        0
# Source bytes                   0
# Destination bytes              0
# Count                          0
# Same srv rate                  0
# Serror rate                    0
# Srv serror rate                0
# Dst host count                 0
# Dst host srv count             0
# Dst host same src port rate    0
# Dst host serror rate           0
# Dst host srv serror rate       0
# Flag                           0
# IDS detection                  0
# Malware detection              0
# Ashula detection               0
# Label                          0
# Source IP Address              0
# Source Port Number             0
# Destination IP Address         0
# Destination Port Number        0
# Start Time                     0
# Protocol                       0
# dtype: int64
# [0 1]
# [1 0]
# [1 0]
# Type of 'Label' column: int64
# Unique values in 'Label' column before mapping:
# [-1  1 -2]
# Type of 'Label' column after mapping: int64
# Unique values in 'Label' column after mapping:
# [1 0]
# Processing chunk 7
# Duration                       0
# Service                        0
# Source bytes                   0
# Destination bytes              0
# Count                          0
# Same srv rate                  0
# Serror rate                    0
# Srv serror rate                0
# Dst host count                 0
# Dst host srv count             0
# Dst host same src port rate    0
# Dst host serror rate           0
# Dst host srv serror rate       0
# Flag                           0
# IDS detection                  0
# Malware detection              0
# Ashula detection               0
# Label                          0
# Source IP Address              0
# Source Port Number             0
# Destination IP Address         0
# Destination Port Number        0
# Start Time                     0
# Protocol                       0
# dtype: int64
# [0 1]
# [1 0]
# [1]
# Type of 'Label' column: int64
# Unique values in 'Label' column before mapping:
# [-1  1]
# Type of 'Label' column after mapping: int64
# Unique values in 'Label' column after mapping:
# [1 0]
# Processing chunk 8
# Duration                       0
# Service                        0
# Source bytes                   0
# Destination bytes              0
# Count                          0
# Same srv rate                  0
# Serror rate                    0
# Srv serror rate                0
# Dst host count                 0
# Dst host srv count             0
# Dst host same src port rate    0
# Dst host serror rate           0
# Dst host srv serror rate       0
# Flag                           0
# IDS detection                  0
# Malware detection              0
# Ashula detection               0
# Label                          0
# Source IP Address              0
# Source Port Number             0
# Destination IP Address         0
# Destination Port Number        0
# Start Time                     0
# Protocol                       0
# dtype: int64
# [0 1]
# [1 0]
# [1 0]
# Type of 'Label' column: int64
# Unique values in 'Label' column before mapping:
# [ 1 -1]
# Type of 'Label' column after mapping: int64
# Unique values in 'Label' column after mapping:
# [0 1]
# Processing chunk 9
# Duration                       0
# Service                        0
# Source bytes                   0
# Destination bytes              0
# Count                          0
# Same srv rate                  0
# Serror rate                    0
# Srv serror rate                0
# Dst host count                 0
# Dst host srv count             0
# Dst host same src port rate    0
# Dst host serror rate           0
# Dst host srv serror rate       0
# Flag                           0
# IDS detection                  0
# Malware detection              0
# Ashula detection               0
# Label                          0
# Source IP Address              0
# Source Port Number             0
# Destination IP Address         0
# Destination Port Number        0
# Start Time                     0
# Protocol                       0
# dtype: int64
# [0 1]
# [0 1]
# [0 1]
# Type of 'Label' column: int64
# Unique values in 'Label' column before mapping:
# [-1  1 -2]
# Type of 'Label' column after mapping: int64
# Unique values in 'Label' column after mapping:
# [1 0]
# Processing chunk 10
# Duration                       0
# Service                        0
# Source bytes                   0
# Destination bytes              0
# Count                          0
# Same srv rate                  0
# Serror rate                    0
# Srv serror rate                0
# Dst host count                 0
# Dst host srv count             0
# Dst host same src port rate    0
# Dst host serror rate           0
# Dst host srv serror rate       0
# Flag                           0
# IDS detection                  0
# Malware detection              0
# Ashula detection               0
# Label                          0
# Source IP Address              0
# Source Port Number             0
# Destination IP Address         0
# Destination Port Number        0
# Start Time                     0
# Protocol                       0
# dtype: int64
# [1 0]
# [0 1]
# [0 1]
# Type of 'Label' column: int64
# Unique values in 'Label' column before mapping:
# [ 1 -1 -2]
# Type of 'Label' column after mapping: int64
# Unique values in 'Label' column after mapping:
# [0 1]
# Processing chunk 11
# Duration                       0
# Service                        0
# Source bytes                   0
# Destination bytes              0
# Count                          0
# Same srv rate                  0
# Serror rate                    0
# Srv serror rate                0
# Dst host count                 0
# Dst host srv count             0
# Dst host same src port rate    0
# Dst host serror rate           0
# Dst host srv serror rate       0
# Flag                           0
# IDS detection                  0
# Malware detection              0
# Ashula detection               0
# Label                          0
# Source IP Address              0
# Source Port Number             0
# Destination IP Address         0
# Destination Port Number        0
# Start Time                     0
# Protocol                       0
# dtype: int64
# [0 1]
# [0 1]
# [0 1]
# Type of 'Label' column: int64
# Unique values in 'Label' column before mapping:
# [-1  1 -2]
# Type of 'Label' column after mapping: int64
# Unique values in 'Label' column after mapping:
# [1 0]
# Processing chunk 12
# Duration                       0
# Service                        0
# Source bytes                   0
# Destination bytes              0
# Count                          0
# Same srv rate                  0
# Serror rate                    0
# Srv serror rate                0
# Dst host count                 0
# Dst host srv count             0
# Dst host same src port rate    0
# Dst host serror rate           0
# Dst host srv serror rate       0
# Flag                           0
# IDS detection                  0
# Malware detection              0
# Ashula detection               0
# Label                          0
# Source IP Address              0
# Source Port Number             0
# Destination IP Address         0
# Destination Port Number        0
# Start Time                     0
# Protocol                       0
# dtype: int64
# [0 1]
# [0 1]
# [0 1]
# Type of 'Label' column: int64
# Unique values in 'Label' column before mapping:
# [-1  1 -2]
# Type of 'Label' column after mapping: int64
# Unique values in 'Label' column after mapping:
# [1 0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115574748 entries, 0 to 115574747
# Data columns (total 24 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Duration                     float64
#  1   Service                      float64
#  2   Source bytes                 float64
#  3   Destination bytes            float64
#  4   Count                        float64
#  5   Same srv rate                float64
#  6   Serror rate                  float64
#  7   Srv serror rate              float64
#  8   Dst host count               float64
#  9   Dst host srv count           float64
#  10  Dst host same src port rate  float64
#  11  Dst host serror rate         float64
#  12  Dst host srv serror rate     float64
#  13  Flag                         float64
#  14  IDS detection                float64
#  15  Malware detection            float64
#  16  Ashula detection             float64
#  17  Label                        float64
#  18  Source IP Address            float64
#  19  Source Port Number           float64
#  20  Destination IP Address       float64
#  21  Destination Port Number      float64
#  22  Start Time                   float64
#  23  Protocol                     float64
# dtypes: float64(24)
# memory usage: 20.7 GB

# %%
# Save the final DataFrame to a Parquet file
df.to_parquet('/content/processed_data.parquet', index=False)

# %%
# !cp /content/processed_data.parquet /content/drive/MyDrive/Kyoto2006+/Kyoto2015_encoded.parquet

# %%
df.shape
# Out:
# (115574748, 24)

# %%
# Print out the DataFrames loaded in the memory
# %whos DataFrame
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# chunk      DataFrame               Duration   Ser<...>574748 rows x 24 columns]
# df         DataFrame

# %%
# !du -sh /content/processed_data.parquet
# Out:
# 1.4G	/content/processed_data.parquet

# %% [markdown]
# ## 2. Algorithm Evaluation
#
# In this section, we assess the performance of various machine learning algorithms on the upper mentioned datasets.

# %% [markdown]
# ### 2.4. Kyoto2015 dataset evaluation with baseline and traditional ML algorithms
#
# In this section, we evaluate the performance of various machine learning algorithms on the Kyoto2015 dataset. We assess the precision and F1 scores, essential indicators of classification accuracy, for a range of algorithms, including fundamental classifiers like Zero Rule and One Rule, statistical approaches like Naive Bayes, and more advanced models such as Random Forest.
#
# Given that the Kyoto2015 is a large dataset, to ensure a robust assessment and be able to employ a 10-fold cross-validation methodology, we sampled the dataset to 10%. These results offer valuable insights into the optimal dataset generation strategy, aiding in the selection of the most effective feature extraction methods for cybersecurity specific dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import pyarrow.parquet as pq

# Specify the path to your Parquet file
parquet_file_path = '/content/drive/MyDrive/Kyoto2006+/Kyoto2015_encoded.parquet'

# Read the Parquet file into a DataFrame
df = pq.read_table(parquet_file_path).to_pandas()

# %%
df.shape
# Out:
# (115574748, 24)

# %%
# Sampling full_df for best features selection
part_df = df.sample(frac=0.01, random_state=42) # Sample 1% of data

# %%
part_df.shape
# Out:
# (1155747, 24)

# %%
label_counts_Kyoto_sample = df['Label'].value_counts()

# Display the counts with labels for df
print("Label counts for the sample from Kyoto 2015:")
print(label_counts_Kyoto_sample)

label_counts_df = part_df['Label'].value_counts()

# Display the counts with labels for part_df
print("\nLabel counts for part_df:")
print(label_counts_df)
# Out:
# Label counts for the sample from Kyoto 2015:
# 1.0    109256672
# 0.0      6318076
# Name: Label, dtype: int64
#
# Label counts for part_df:
# 1.0    1092952
# 0.0      62795
# Name: Label, dtype: int64

# %%
del df

import gc
gc.collect()
# Out:
# 0

# %%
# Separate features (X) and labels (y)
X = part_df.drop('Label', axis=1)  # Exclude the label column
y = part_df['Label']

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_classif

# Create a pipeline for feature selection on the preprocessed data
pipeline_10_features = Pipeline([
    ('selector_10', SelectKBest(score_func=f_classif, k=10))
])

pipeline_20_features = Pipeline([
    ('selector_20', SelectKBest(score_func=f_classif, k=20))
])

# Fit and transform the data for 10 and 20 features
X_selected_10 = pipeline_10_features.fit_transform(X, y)
X_selected_20 = pipeline_20_features.fit_transform(X, y)

# Display the selected features
print(X_selected_10.shape)  # Check the shape of the selected 10 features
print(X_selected_20.shape)  # Check the shape of the selected 20 features

# Display the selected features
print("Selected 10 features:")
selected_feature_indices_10 = pipeline_10_features.named_steps['selector_10'].get_support(indices=True)
selected_features_10 = X.columns[selected_feature_indices_10]
print(selected_features_10)

print("\nSelected 20 features:")
selected_feature_indices_20 = pipeline_20_features.named_steps['selector_20'].get_support(indices=True)
selected_features_20 = X.columns[selected_feature_indices_20]
print(selected_features_20)
# Out:
# (1155747, 10)
# (1155747, 20)
# Selected 10 features:
# Index(['Duration', 'Same srv rate', 'Srv serror rate', 'Dst host count',
#        'Dst host srv count', 'Dst host srv serror rate', 'Flag',
#        'IDS detection', 'Source Port Number', 'Protocol'],
#       dtype='object')
#
# Selected 20 features:
# Index(['Duration', 'Service', 'Count', 'Same srv rate', 'Serror rate',
#        'Srv serror rate', 'Dst host count', 'Dst host srv count',
#        'Dst host same src port rate', 'Dst host serror rate',
#        'Dst host srv serror rate', 'Flag', 'IDS detection', 'Ashula detection',
#        'Source IP Address', 'Source Port Number', 'Destination IP Address',
#        'Destination Port Number', 'Start Time', 'Protocol'],
#       dtype='object')

# %%
selected_features_10 = ['Duration', 'Same srv rate', 'Srv serror rate', 'Dst host count',
       'Dst host srv count', 'Dst host srv serror rate', 'Flag',
       'IDS detection', 'Source Port Number', 'Protocol']
print(selected_features_10)
selected_features_20 = ['Duration', 'Service', 'Count', 'Same srv rate', 'Serror rate',
       'Srv serror rate', 'Dst host count', 'Dst host srv count',
       'Dst host same src port rate', 'Dst host serror rate',
       'Dst host srv serror rate', 'Flag', 'IDS detection', 'Ashula detection',
       'Source IP Address', 'Source Port Number', 'Destination IP Address',
       'Destination Port Number', 'Start Time', 'Protocol']
print(selected_features_20)
# Out:
# ['Duration', 'Same srv rate', 'Srv serror rate', 'Dst host count', 'Dst host srv count', 'Dst host srv serror rate', 'Flag', 'IDS detection', 'Source Port Number', 'Protocol']
# ['Duration', 'Service', 'Count', 'Same srv rate', 'Serror rate', 'Srv serror rate', 'Dst host count', 'Dst host srv count', 'Dst host same src port rate', 'Dst host serror rate', 'Dst host srv serror rate', 'Flag', 'IDS detection', 'Ashula detection', 'Source IP Address', 'Source Port Number', 'Destination IP Address', 'Destination Port Number', 'Start Time', 'Protocol']

# %%
import warnings
import os
import pandas as pd
import numpy as np
from sklearn.metrics import precision_score, mean_absolute_error, f1_score
from sklearn.dummy import DummyClassifier
from tabulate import tabulate
import time
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

# Define the number of desired folds for Cross-Validation (e.g., 10)
num_folds = 10

# Initialize performance metrics lists for 10 and 20 features
results_10_features = []
results_20_features = []

# Suppress all warning messages
warnings.filterwarnings("ignore")

# %%
# Specify the destination folder in your Google Drive
destination_folder = "/content/drive/MyDrive/Kyoto2006+/"

# Define a file name for saving the results
results_file_name = os.path.join(destination_folder, "kyoto2015_results.pkl")

# Check for results before rerunning the code snippet
if not os.path.exists(results_file_name):

  # Define ZeroRule classifier
  zero_rule = DummyClassifier(strategy="most_frequent")

  # Evaluate ZeroRule classifier
  start_time = time.time()  # Start measuring execution time
  precision_scores_10 = cross_val_score(zero_rule, X[selected_features_10], y, cv=num_folds, scoring='precision')
  f1_scores_10 = cross_val_score(zero_rule, X[selected_features_10], y, cv=num_folds, scoring='f1')
  elapsed_time_10 = time.time() - start_time  # Calculate execution time

  start_time = time.time()  # Start measuring execution time
  precision_scores_20 = cross_val_score(zero_rule, X[selected_features_20], y, cv=num_folds, scoring='precision')
  f1_scores_20 = cross_val_score(zero_rule, X[selected_features_20], y, cv=num_folds, scoring='f1')
  elapsed_time_20 = time.time() - start_time  # Calculate execution time

  variance_10 = np.var(precision_scores_10)
  variance_20 = np.var(precision_scores_20)

  predictions_10 = cross_val_predict(zero_rule, X[selected_features_10], y, cv=num_folds)
  mae_10 = mean_absolute_error(y, predictions_10)

  predictions_20 = cross_val_predict(zero_rule, X[selected_features_20], y, cv=num_folds)
  mae_20 = mean_absolute_error(y, predictions_20)

  # Display ZeroRule results for 10 features
  print("ZeroRule Precision (10 features):", np.mean(precision_scores_10))
  print("ZeroRule F1 Score (10 features):", np.mean(f1_scores_10))
  print("ZeroRule Variance (10 features):", variance_10)
  print("ZeroRule MAE (10 features):", mae_10)
  print("ZeroRule Execution Time:", elapsed_time_10)

  # Display ZeroRule results for 20 features
  print("ZeroRule Precision (20 features):", np.mean(precision_scores_20))
  print("ZeroRule F1 Score (20 features):", np.mean(f1_scores_20))
  print("ZeroRule Variance (20 features):", variance_20)
  print("ZeroRule MAE (20 features):", mae_20)
  print("ZeroRule Execution Time:", elapsed_time_20)

  results_10_features.append(["ZeroRule", np.mean(precision_scores_10), np.mean(f1_scores_10), variance_10, mae_10, elapsed_time_10])
  results_20_features.append(["ZeroRule", np.mean(precision_scores_20), np.mean(f1_scores_20), variance_20, mae_20, elapsed_time_20])
# Out:
# ZeroRule Precision (10 features): 0.9456671745736667
# ZeroRule F1 Score (10 features): 0.9720749642355937
# ZeroRule Variance (10 features): 1.7542188112392676e-11
# ZeroRule MAE (10 features): 0.0543328254367089
# ZeroRule Execution Time: 3.944232702255249
# ZeroRule Precision (20 features): 0.9456671745736667
# ZeroRule F1 Score (20 features): 0.9720749642355937
# ZeroRule Variance (20 features): 1.7542188112392676e-11
# ZeroRule MAE (20 features): 0.0543328254367089
# ZeroRule Execution Time: 4.807303428649902

# %%
# Check for results before rerunning the code snippet
if not os.path.exists(results_file_name):

  # Define OneRule classifier
  one_rule = DummyClassifier(strategy="stratified")

  # Evaluate OneRule classifier
  start_time = time.time()  # Start measuring execution time
  precision_scores_10 = cross_val_score(one_rule, X[selected_features_10], y, cv=num_folds, scoring='precision')
  f1_scores_10 = cross_val_score(one_rule, X[selected_features_10], y, cv=num_folds, scoring='f1')
  elapsed_time_10 = time.time() - start_time  # Calculate execution time

  start_time = time.time()  # Start measuring execution time
  precision_scores_20 = cross_val_score(one_rule, X[selected_features_20], y, cv=num_folds, scoring='precision')
  f1_scores_20 = cross_val_score(one_rule, X[selected_features_20], y, cv=num_folds, scoring='f1')
  elapsed_time_20 = time.time() - start_time  # Calculate execution time

  variance_10 = np.var(precision_scores_10)
  variance_20 = np.var(precision_scores_20)

  predictions_10 = cross_val_predict(one_rule, X[selected_features_10], y, cv=num_folds)
  mae_10 = mean_absolute_error(y, predictions_10)

  predictions_20 = cross_val_predict(one_rule, X[selected_features_20], y, cv=num_folds)
  mae_20 = mean_absolute_error(y, predictions_20)

  # Display OneRule results for 10 features
  print("OneRule Precision (10 features):", np.mean(precision_scores_10))
  print("OneRule F1 Score (10 features):", np.mean(f1_scores_10))
  print("OneRule Variance (10 features):", variance_10)
  print("OneRule MAE (10 features):", mae_10)
  print("OneRule Execution Time:", elapsed_time_10)

  # Display OneRule results for 20 features
  print("OneRule Precision (20 features):", np.mean(precision_scores_20))
  print("OneRule F1 Score (20 features):", np.mean(f1_scores_20))
  print("OneRule Variance (20 features):", variance_20)
  print("OneRule MAE (20 features):", mae_20)
  print("OneRule Execution Time:", elapsed_time_20)

  results_10_features.append(["OneRule", np.mean(precision_scores_10), np.mean(f1_scores_10), variance_10, mae_10, elapsed_time_10])
  results_20_features.append(["OneRule", np.mean(precision_scores_20), np.mean(f1_scores_20), variance_20, mae_20, elapsed_time_20])
# Out:
# OneRule Precision (10 features): 0.9456520870501178
# OneRule F1 Score (10 features): 0.9456875593971354
# OneRule Variance (10 features): 4.3971115713171974e-08
# OneRule MAE (10 features): 0.10311253241410101
# OneRule Execution Time: 3.9662866592407227
# OneRule Precision (20 features): 0.9455930155581648
# OneRule F1 Score (20 features): 0.9454977602039143
# OneRule Variance (20 features): 1.9497232018266623e-08
# OneRule MAE (20 features): 0.10294207988426533
# OneRule Execution Time: 4.468806028366089

# %%
# Check for results before rerunning the code snippet
if not os.path.exists(results_file_name):

  # Define Naive Bayes classifier
  naive_bayes = GaussianNB()

  # Evaluate Naive Bayes classifier
  start_time = time.time()  # Start measuring execution time
  precision_scores_10 = cross_val_score(naive_bayes, X[selected_features_10], y, cv=num_folds, scoring='precision')
  f1_scores_10 = cross_val_score(naive_bayes, X[selected_features_10], y, cv=num_folds, scoring='f1')
  elapsed_time_10 = time.time() - start_time  # Calculate execution time

  start_time = time.time()  # Start measuring execution time
  precision_scores_20 = cross_val_score(naive_bayes, X[selected_features_20], y, cv=num_folds, scoring='precision')
  f1_scores_20 = cross_val_score(naive_bayes, X[selected_features_20], y, cv=num_folds, scoring='f1')
  elapsed_time_20 = time.time() - start_time  # Calculate execution time

  variance_10 = np.var(precision_scores_10)
  variance_20 = np.var(precision_scores_20)

  predictions_10 = cross_val_predict(naive_bayes, X[selected_features_10], y, cv=num_folds)
  mae_10 = mean_absolute_error(y, predictions_10)

  predictions_20 = cross_val_predict(naive_bayes, X[selected_features_20], y, cv=num_folds)
  mae_20 = mean_absolute_error(y, predictions_20)

  # Display Naive Bayes results for 10 features
  print("Naive Bayes Precision (10 features):", np.mean(precision_scores_10))
  print("Naive Bayes F1 Score (10 features):", np.mean(f1_scores_10))
  print("Naive Bayes Variance (10 features):", variance_10)
  print("Naive Bayes MAE (10 features):", mae_10)
  print("Naive Bayes Execution Time:", elapsed_time_10)

  # Display Naive Bayes results for 20 features
  print("Naive Bayes Precision (20 features):", np.mean(precision_scores_20))
  print("Naive Bayes F1 Score (20 features):", np.mean(f1_scores_20))
  print("Naive Bayes Variance (20 features):", variance_20)
  print("Naive Bayes MAE (20 features):", mae_20)
  print("Naive Bayes Execution Time:", elapsed_time_20)

  results_10_features.append(["Naive Bayes", np.mean(precision_scores_10), np.mean(f1_scores_10), variance_10, mae_10, elapsed_time_10])
  results_20_features.append(["Naive Bayes", np.mean(precision_scores_20), np.mean(f1_scores_20), variance_20, mae_20, elapsed_time_20])
# Out:
# Naive Bayes Precision (10 features): 0.9756340305288976
# Naive Bayes F1 Score (10 features): 0.8469311043933752
# Naive Bayes Variance (10 features): 3.871468417651549e-07
# Naive Bayes MAE (10 features): 0.25576445363907496
# Naive Bayes Execution Time: 8.66162395477295
# Naive Bayes Precision (20 features): 0.9849695525937443
# Naive Bayes F1 Score (20 features): 0.7888414911851874
# Naive Bayes Variance (20 features): 3.0192939254192053e-07
# Naive Bayes MAE (20 features): 0.3330529951624361
# Naive Bayes Execution Time: 12.879241466522217

# %%
# Check for results before rerunning the code snippet
if not os.path.exists(results_file_name):

  # Create a Random Forest classifier with optimized parameters
  rf_classifier = RandomForestClassifier(n_estimators=100, max_depth=10, n_jobs=-1)  # Adjust parameters for optimization

  # Evaluate Random Forest classifier
  start_time = time.time()  # Start measuring execution time
  precision_scores_10 = cross_val_score(rf_classifier, X[selected_features_10], y, cv=num_folds, scoring='precision')
  print("Random Forest Precision (10 features):", np.mean(precision_scores_10))
  f1_scores_10 = cross_val_score(rf_classifier, X[selected_features_10], y, cv=num_folds, scoring='f1')
  print("Random Forest F1 Score (10 features):", np.mean(f1_scores_10))
  elapsed_time_10 = time.time() - start_time  # Calculate execution time
  print("Random Forest Execution Time:", elapsed_time_10)

  start_time = time.time()  # Start measuring execution time
  precision_scores_20 = cross_val_score(rf_classifier, X[selected_features_20], y, cv=num_folds, scoring='precision')
  print("Random Forest Precision (20 features):", np.mean(precision_scores_20))
  f1_scores_20 = cross_val_score(rf_classifier, X[selected_features_20], y, cv=num_folds, scoring='f1')
  print("Random Forest F1 Score (20 features):", np.mean(f1_scores_20))
  elapsed_time_20 = time.time() - start_time  # Calculate execution time
  print("Random Forest Execution Time:", elapsed_time_20)

  variance_10 = np.var(precision_scores_10)
  print("Random Forest Variance (10 features):", variance_10)
  variance_20 = np.var(precision_scores_20)
  print("Random Forest Variance (20 features):", variance_20)

  predictions_10 = cross_val_predict(rf_classifier, X[selected_features_10], y, cv=num_folds)
  mae_10 = mean_absolute_error(y, predictions_10)
  print("Random Forest MAE (10 features):", mae_10)

  predictions_20 = cross_val_predict(rf_classifier, X[selected_features_20], y, cv=num_folds)
  mae_20 = mean_absolute_error(y, predictions_20)
  print("Random Forest MAE (20 features):", mae_20)

  results_10_features.append(["Random Forest", np.mean(precision_scores_10), np.mean(f1_scores_10), variance_10, mae_10, elapsed_time_10])
  results_20_features.append(["Random Forest", np.mean(precision_scores_20), np.mean(f1_scores_20), variance_20, mae_20, elapsed_time_20])
# Out:
# Random Forest Precision (10 features): 0.9645078006289648
# Random Forest F1 Score (10 features): 0.9800951847154471
# Random Forest Execution Time: 546.3033177852631
# Random Forest Precision (20 features): 0.9678073230157805
# Random Forest F1 Score (20 features): 0.9831671487583508
# Random Forest Execution Time: 757.6577804088593
# Random Forest Variance (10 features): 1.9547026574542038e-07
# Random Forest Variance (20 features): 6.89779269292472e-07
# Random Forest MAE (10 features): 0.03820905440377522
# Random Forest MAE (20 features): 0.032241485376989946

# %%
import pickle
import os

if not os.path.exists(results_file_name):

  # Save the results lists to a file
  with open(results_file_name, 'wb') as file:
      results_dict = {
          'results_10_features': results_10_features,
          'results_20_features': results_20_features
      }
      pickle.dump(results_dict, file)

# %%
import pickle, os

# Specify the destination folder in your Google Drive
destination_folder = "/content/drive/MyDrive/Kyoto2006+/"

# Define a file name for saving the results
results_file_name = os.path.join(destination_folder, "kyoto2015_results.pkl")

# Load the results from the file
with open(results_file_name, 'rb') as file:
    loaded_results = pickle.load(file)

# Access the loaded results lists
results_10_features = loaded_results['results_10_features']
results_20_features = loaded_results['results_20_features']

# %%
from tabulate import tabulate

# Print the results in tabular format
headers_10 = ["Algorithm", "Precision (10 Features)", "F1 Score (10 Features)", "Variance (10 Features)", "MAE (10 Features)", "Execution Time"]
headers_20 = ["Precision (20 Features)", "F1 Score (20 Features)", "Variance (20 Features)", "MAE (20 Features)", "Execution Time"]

print(tabulate(results_10_features, headers_10, tablefmt="pretty"))
print(tabulate(results_20_features, headers_20, tablefmt="pretty"))
# Out:
# +---------------+-------------------------+------------------------+------------------------+---------------------+--------------------+
# |   Algorithm   | Precision (10 Features) | F1 Score (10 Features) | Variance (10 Features) |  MAE (10 Features)  |   Execution Time   |
# +---------------+-------------------------+------------------------+------------------------+---------------------+--------------------+
# |   ZeroRule    |   0.9456671745736667    |   0.9720749642355937   | 1.7542188112392676e-11 | 0.0543328254367089  | 3.944232702255249  |
# |    OneRule    |   0.9456520870501178    |   0.9456875593971354   | 4.3971115713171974e-08 | 0.10311253241410101 | 3.9662866592407227 |
# |  Naive Bayes  |   0.9756340305288976    |   0.8469311043933752   | 3.871468417651549e-07  | 0.25576445363907496 |  8.66162395477295  |
# | Random Forest |   0.9645078006289648    |   0.9800951847154471   | 1.9547026574542038e-07 | 0.03820905440377522 | 546.3033177852631  |
# +---------------+-------------------------+------------------------+------------------------+---------------------+--------------------+
# +---------------+-------------------------+------------------------+------------------------+----------------------+--------------------+
# |               | Precision (20 Features) | F1 Score (20 Features) | Variance (20 Features) |  MAE (20 Features)   |   Execution Time   |
# +---------------+-------------------------+------------------------+------------------------+----------------------+--------------------+
# |   ZeroRule    |   0.9456671745736667    |   0.9720749642355937   | 1.7542188112392676e-11 |  0.0543328254367089  | 4.807303428649902  |
# |    OneRule    |   0.9455930155581648    |   0.9454977602039143   | 1.9497232018266623e-08 | 0.10294207988426533  | 4.468806028366089  |
# |  Naive Bayes  |   0.9849695525937443    |   0.7888414911851874   | 3.0192939254192053e-07 |  0.3330529951624361  | 12.879241466522217 |
# | Random Forest |   0.9678073230157805    |   0.9831671487583508   |  6.89779269292472e-07  | 0.032241485376989946 | 757.6577804088593  |
# +---------------+-------------------------+------------------------+------------------------+----------------------+--------------------+
