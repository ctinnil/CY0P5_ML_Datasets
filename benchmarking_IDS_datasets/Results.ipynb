# %% [markdown]
# # Results
#
# ## KDD99
#
# |   Algorithm   | Precision (10 Features) | F1 Score (10 Features) | Variance (10 Features) |  MAE (10 Features)   |   Execution Time   |
#  |--- |--- |--- |--- |--- |--- |
# |   ZeroRule    |           0.0           |          0.0           |          0.0           | 0.24388199627342944  | 2.3789751529693604 |
# |    OneRule    |   0.24312432230925718   |  0.24395697630241897   | 4.267845198669343e-06  |  0.3688383909326938  | 2.6188907623291016 |
# |  Naive Bayes  |   0.9479421362435112    |   0.9557347237986116   |  0.004133212375383223  | 0.022359423358322875 | 6.8374340534210205 |
# | Random Forest |    0.998262408241796    |   0.9799685338553014   | 5.231475371684771e-06  | 0.009168517083525972 | 169.15548610687256 |
#
# |               | Precision (20 Features) | F1 Score (20 Features) | Variance (20 Features) |  MAE (20 Features)   |   Execution Time   |
#  |--- |--- |--- |--- |--- |--- |
# |   ZeroRule    |           0.0           |          0.0           |          0.0           | 0.24388199627342944  | 3.2261602878570557 |
# |    OneRule    |   0.2441829909978038    |  0.24404729271675052   | 6.391651230681625e-06  | 0.36822628822967435  | 3.214223623275757  |
# |  Naive Bayes  |   0.9471108890560659    |   0.9555713098731035   |  0.007137480410507853  | 0.023257111972933526 | 10.366659879684448 |
# | Random Forest |   0.9980822403663654    |   0.9884509989637585   | 5.116359534341992e-06  | 0.005495900865409034 | 210.78380870819092 |
#
# ## NSL-KDD
#
# |   Algorithm   | Precision (10 Features) | F1 Score (10 Features) | Variance (10 Features) |  MAE (10 Features)  |   Execution Time    |
#  |--- |--- |--- |--- |--- |--- |
# |   ZeroRule    |           0.0           |          0.0           |          0.0           | 0.4653826917428134  | 0.33173060417175293 |
# |    OneRule    |   0.4643182608755576    |   0.4676192412419926   | 2.8877747352643335e-05 | 0.49847177345728505 | 0.35054945945739746 |
# |  Naive Bayes  |   0.9483081080571318    |   0.8513815314023855   | 1.0650856542257133e-05 | 0.12549716980383127 |  0.871079683303833  |
# | Random Forest |   0.9796262301079197    |   0.9417613889654819   |  4.37806350207662e-06  | 0.05175329263355112 | 20.291851043701172  |
#
# |               | Precision (20 Features) | F1 Score (20 Features) | Variance (20 Features) |  MAE (20 Features)  |   Execution Time    |
#  |--- |--- |--- |--- |--- |--- |
# |   ZeroRule    |           0.0           |          0.0           |          0.0           |  0.4653826917428134   | 0.4054434299468994  |
# |    OneRule    |   0.4671072998119078    |  0.46345174992136096   | 1.0105616426021796e-05 |  0.4969713328517104   | 0.41045117378234863 |
# |  Naive Bayes  |   0.9021495902238075    |   0.8914635876869642   | 3.2140929322479728e-06 |  0.09983884156458643  |  1.361576795578003  |
# | Random Forest |   0.9960979771716556    |   0.9963425200700451   | 1.479463741300512e-06  | 0.0034137008486619085 | 24.775439739227295  |
#
# ## CTU-13
#
# |   Algorithm   |      Precision       |       F1 Score       |        Variance        |         MAE          |   Execution Time   |
#  |--- |--- |--- |--- |--- |--- |
# |   ZeroRule    |         0.0          |         0.0          |          0.0           | 0.024866100215566744 | 30.797607898712158 |
# |    OneRule    | 0.024784734503328354 | 0.02493287194553043  | 8.980152971872171e-07  | 0.04843010159029388  |  31.0071804523468  |
# |  Naive Bayes  | 0.02939298880167533  |  0.0570083052333196  | 2.0994859580674664e-05 |  0.7805218561198326  | 68.04527616500854  |
# | Random Forest |  0.6757534659433394  | 0.039739922209714736 |  0.18238869891010404   | 0.024287838598867212 | 4184.681151866913  |
#
# ## ISCXIIDS2012
#
# |   Algorithm   |     Precision      |      F1 Score       |        Variance        |         MAE          |   Execution Time   |
#  |--- |--- |--- |--- |--- |--- |
# |   ZeroRule    |        0.0         |         0.0         |          0.0           | 0.03279891691167001  | 5.6921117305755615 |
# |    OneRule    | 0.0333212537210722 | 0.03162443842440634 | 4.3234639380297525e-06 | 0.06329867442460932  | 5.965609788894653  |
# |  Naive Bayes  | 0.2786100231779066 | 0.4317346957207556  |  0.001716265973914469  | 0.08639872514045455  | 14.252134561538696 |
# | Random Forest | 0.9460547155556993 | 0.8910964816398075  |  0.025444219779817073  | 0.007293098762792194 | 1023.1033320426941 |
#
# ## CICIDS2017
#
# |   Algorithm   | Precision (10 Features) | F1 Score (10 Features) | Variance (10 Features) |  MAE (10 Features)  |   Execution Time   |
#  |--- |--- |--- |--- |--- |--- |
# |   ZeroRule    |           0.0           |          0.0           |          0.0           | 0.16885152950972424 | 5.741321802139282  |
# |    OneRule    |   0.1688648087046783    |  0.16824311673945386   | 1.5092077832251044e-06 | 0.28086754822465854 | 6.198862314224243  |
# |  Naive Bayes  |   0.5401359055040736    |   0.5455170076570558   |  0.07693411707006614   | 0.1255934656331159  | 15.011318445205688 |
# | Random Forest |   0.9893039075931785    |   0.9277228280954881   | 4.655091528474845e-05  | 0.0188723459090819  | 521.3329920768738  |
#
# |               | Precision (20 Features) | F1 Score (20 Features) | Variance (20 Features) |  MAE (20 Features)   |   Execution Time   |
#  |--- |--- |--- |--- |--- |--- |
# |   ZeroRule    |           0.0           |          0.0           |          0.0           | 0.16885152950972424  | 8.154945850372314  |
# |    OneRule    |   0.1690042791642603    |   0.1690999895153959   | 1.9157845758286896e-06 |  0.2807485973711861  | 8.574870109558105  |
# |  Naive Bayes  |   0.49268026231647066   |   0.5347929048673781   |   0.0633147173244346   | 0.14097301798140402  | 25.839256286621094 |
# | Random Forest |   0.9900622819449969    |   0.9311988646306373   | 0.00016571417330496935 | 0.018215340695069488 | 598.3411316871643  |
#
# ## CSE-CIC-IDS2018
#
# |   Algorithm   | Precision (10 Features) | F1 Score (10 Features) | Variance (10 Features) |  MAE (10 Features)  |  Execution Time   |
#  |--- |--- |--- |--- |--- |--- |
# |   ZeroRule    |           0.0           |          0.0           |          0.0           | 0.17546362166335652 | 6.306824445724487 |
# |    OneRule    |   0.17517836333508166   |   0.1767940417061407   | 5.111938572730934e-06  | 0.28907945788193246 | 6.406144380569458 |
# |  Naive Bayes  |    0.41599489156053     |   0.5771099044320416   |  0.00356662793445076   | 0.25114964575857196 | 29.47931957244873 |
# | Random Forest |    0.999590366459798    |   0.9913011147144981   |  7.52042520972457e-08  | 0.00301675787756212 | 1010.446768283844 |
#
# |               | Precision (20 Features) | F1 Score (20 Features) | Variance (20 Features) |   MAE (20 Features)   |   Execution Time   |
#  |--- |--- |--- |--- |--- |--- |
# |   ZeroRule    |           0.0           |          0.0           |          0.0           |  0.17546362166335652  | 10.245831727981567 |
# |    OneRule    |   0.17525141166993846   |  0.17562117159784002   | 9.781975488477432e-06  |  0.2891073795846222   | 10.43408989906311  |
# |  Naive Bayes  |   0.8649107572972674    |    0.90647044053673    |  0.002068585229766033  | 0.034690894611354176  | 56.40955948829651  |
# | Random Forest |   0.9945822263846985    |   0.996695095080631    | 0.00022476785402515898 | 0.0013050361039755648 | 436.4050407409668  |
#
# ## CIDDS-001
#
# |   Algorithm   | Precision (10 Features) | F1 Score (10 Features) | Variance (10 Features) |  MAE (10 Features)  |   Execution Time   |
#  |--- |--- |--- |--- |--- |--- |
# |   ZeroRule    |   0.9537592977784136    |   0.9763324467478158   | 1.019999700573365e-12  | 0.04624070222247505 | 12.883915424346924 |
# |    OneRule    |   0.9537773273918637    |   0.9538478847474007   | 4.413383010722671e-09  | 0.0882918421779393  | 13.098495483398438 |
# |  Naive Bayes  |   0.9997120212972236    |   0.7879164635006519   | 2.004666101080834e-07  | 0.3312410371122046  | 29.050339698791504 |
# | Random Forest |   0.9917123946520192    |   0.9931495419866885   |  6.16212472092088e-06  | 0.01292789044243062 | 1359.8828287124634 |
#
# |               | Precision (All Features) | F1 Score (All Features) | Variance (All Features) |  MAE (All Features)  |   Execution Time   |
#  |--- |--- |--- |--- |--- |--- |
# |   ZeroRule    |    0.9537592977784136    |   0.9763324467478158    |  1.019999700573365e-12  | 0.04624070222247505  | 13.03194785118103  |
# |    OneRule    |    0.9537679484558573    |   0.9537241920462541    | 3.1644697947857035e-09  | 0.08810535906142795  | 13.448907136917114 |
# |  Naive Bayes  |    0.9997120212972236    |   0.7879164635006519    |  2.004666101080834e-07  |  0.3312410371122046  | 30.547858238220215 |
# | Random Forest |    0.991550803132497     |    0.993007494486938    |  5.994781715860138e-06  | 0.013212317336002664 | 1249.062584400177  |
#
# ## CIDDS-002
#
# |   Algorithm   | Precision (10 Features) | F1 Score (10 Features) | Variance (10 Features) |   MAE (10 Features)   |  Execution Time   |
#  |--- |--- |--- |--- |--- |--- |
# |   ZeroRule    |   0.9990820043357116    |   0.9995407913912411   | 3.432257141571462e-12  | 0.0009179956665761032 | 7.76543402671814  |
# |    OneRule    |   0.9990818963973034    |   0.9990807807186062   | 6.369223916299419e-12  | 0.0018303153500530136 | 7.572270393371582 |
# |  Naive Bayes  |   0.9998023905157524    |   0.991570605014851    | 1.9865065199076738e-08 |  0.01663100887950796  | 18.78332757949829 |
# | Random Forest |   0.9997746924085155    |   0.9998458617385355   | 2.5497527179143414e-08 | 0.0003068814862296866 | 869.8524992465973 |
#
# |               | Precision (All Features) | F1 Score (All Features) | Variance (All Features) |   MAE (All Features)   |   Execution Time   |
#  |--- |--- |--- |--- |--- |--- |
# |   ZeroRule    |    0.9990820043357116    |   0.9995407913912411    |  3.432257141571462e-12  | 0.0009179956665761032  | 8.051806211471558  |
# |    OneRule    |    0.9990815319486218    |   0.9990777471249151    | 3.5620273362099803e-12  | 0.0018185849849813487  | 7.493360996246338  |
# |  Naive Bayes  |    0.9998023905157524    |    0.991570605014851    | 1.9865065199076738e-08  |  0.01663100887950796   | 19.702195405960083 |
# | Random Forest |    0.9997750715705503    |   0.9998477556557137    | 2.5697755547220984e-08  | 0.00030574628960984806 | 794.2905073165894  |
#
# ## Kyoto
#
# |   Algorithm   | Precision (10 Features) | F1 Score (10 Features) | Variance (10 Features) |   MAE (10 Features)   |  Execution Time   |
#  |--- |--- |--- |--- |--- |--- |
# |   ZeroRule    |   0.9990820043357116    |   0.9995407913912411   | 3.432257141571462e-12  | 0.0009179956665761032 | 7.76543402671814  |
# |    OneRule    |   0.9990818963973034    |   0.9990807807186062   | 6.369223916299419e-12  | 0.0018303153500530136 | 7.572270393371582 |
# |  Naive Bayes  |   0.9998023905157524    |   0.991570605014851    | 1.9865065199076738e-08 |  0.01663100887950796  | 18.78332757949829 |
# | Random Forest |   0.9997746924085155    |   0.9998458617385355   | 2.5497527179143414e-08 | 0.0003068814862296866 | 869.8524992465973 |
#
# |               | Precision (All Features) | F1 Score (All Features) | Variance (All Features) |   MAE (All Features)   |   Execution Time   |
#  |--- |--- |--- |--- |--- |--- |
# |   ZeroRule    |    0.9990820043357116    |   0.9995407913912411    |  3.432257141571462e-12  | 0.0009179956665761032  | 8.051806211471558  |
# |    OneRule    |    0.9990815319486218    |   0.9990777471249151    | 3.5620273362099803e-12  | 0.0018185849849813487  | 7.493360996246338  |
# |  Naive Bayes  |    0.9998023905157524    |    0.991570605014851    | 1.9865065199076738e-08  |  0.01663100887950796   | 19.702195405960083 |
# | Random Forest |    0.9997750715705503    |   0.9998477556557137    | 2.5697755547220984e-08  | 0.00030574628960984806 | 794.2905073165894  |
#
# ## DL evaluatiion
#
# No|Metric | Model | Dataset | Accuracy | F1 Score
# ---|---|---|---|---|---
# 0 |FFN |ISCXIDS2012 |0.991841 |0.882332
# 1 |FFN |Kyoto2015 |0.958650 |0.978498
# 2 |FFN |cicids2017 |0.964763 |0.887688
# 3 |FFN |cidds001 |0.960476 |0.979647
# 4 |FFN |cidds002 |0.999669 |0.999834
# 5 |FFN |cse-cic-ids2018 |0.971457 |0.871721
# 6 |FFN |ctu13 |0.976128 |0.084161
# 7 |FFN |kdd99 |0.992181 |0.983696
# 8 |FFN |nsl |0.939229 |0.934654
# 9 |TabNet |ISCXIDS2012 |0.967161 |0.000000
# 10 |TabNet |Kyoto2015 |0.942747 |0.970479
# 11 |TabNet |cicids2017 |0.830788 |0.000094
# 12 |TabNet |cidds001 |0.953648 |0.976219
# 13 |TabNet |cidds002 |0.999128 |0.999564
# 14 |TabNet |cse-cic-ids2018 |0.889401 |0.000000
# 15 |TabNet |ctu13 |0.975295 |0.000000
# 16 |TabNet |kdd99 |0.944228 |0.291046
# 17 |TabNet |nsl |0.819752 |0.761540

# %%
import matplotlib.colors as mcolors

# Define a lighter color palette
extended_palette = [sns.light_palette("#FF0000", n_colors=5)[2],
                    sns.light_palette("#0000FF", n_colors=5)[2],
                    sns.light_palette("#00FF00", n_colors=5)[2]]

# Convert the extended_palette to a colormap object
colormap = mcolors.LinearSegmentedColormap.from_list("CustomColormap", extended_palette)

plt.figure(figsize=(12, 6))
sns.heatmap(df_heatmap, annot=True, fmt=".2f", cmap=colormap)
plt.title('Heatmap of F1 Scores for Different Algorithms Across Datasets')
plt.show()

# %%
# Adjusted blue shades to match the number of bars
extended_palette = sns.light_palette("#0000FF", n_colors=2)[1:3] * 9

# Data
data = {
    "Dataset": ["KDD", "NSL-KDD", "CTU-13", "ISCXIIDS2012", "CICIDS2017", "CSE-CIC-IDS2018", "CIDDS-001", "CIDDS-002", "Kyoto"],
    "MAE": [ 0.009168517083525972, 	 0.05175329263355112, 	 0.024287838598867212, 	 0.007293098762792194, 	 0.0188723459090819, 	 0.00301675787756212, 	 0.01292789044243062, 	 0.0003068814862296866, 	 0.0003068814862296866 ]
}
df = pd.DataFrame(data)

# Plot
plt.figure(figsize=(14, 7))
barplot = sns.barplot(x="Dataset", y="MAE", data=df, palette=extended_palette)

# Annotate bars with MAE values
for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.5f'),
                     (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha='center', va='center',
                     xytext=(0, 9),
                     textcoords='offset points',
                     rotation=90)

# Plot settings
plt.title("Mean Absolute Error (MAE) of RandomForest Across Different Datasets")
plt.xlabel("Dataset")
plt.ylabel("MAE")
plt.xticks(rotation=45)
plt.tight_layout()

# Show plot
plt.show()
